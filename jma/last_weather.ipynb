# %% [markdown]
# ##  main.dbの作成

# %%
import requests
import sqlite3

# URLからJSONデータを取得
url = "http://www.jma.go.jp/bosai/common/const/area.json"
response = requests.get(url)

# レスポンスのエンコーディングをUTF-8に設定
response.encoding = 'utf-8'

# JSONデータをPythonの辞書として解析
area_json = response.json()

# "centers" キー内のデータを取得
centers = area_json.get("centers", {})

# SQLiteデータベース接続
db_filename = 'area_info.db'
conn = sqlite3.connect(db_filename)
cursor = conn.cursor()

# テーブルの作成（もしテーブルが存在しない場合）
cursor.execute("""
CREATE TABLE IF NOT EXISTS area_info (
    id INTEGER PRIMARY KEY,
    area_code TEXT,
    area_name TEXT,
    en_name TEXT,
    office_name TEXT,
    children_code TEXT
)
""")

# idの初期化
id_counter = 1

# 各エリア情報をSQLiteデータベースに挿入
for area_code, area_info in centers.items():
    name = area_info.get("name", "N/A")
    enName = area_info.get("enName", "N/A")
    officeName = area_info.get("officeName", "N/A")
    children = area_info.get("children", [])

    # 親エリアの情報をSQLiteに書き込む
    if children:
        for region_code in children:
            # 子エリアIDを挿入
            cursor.execute("""
            INSERT INTO area_info (id, area_code, area_name, en_name, office_name, children_code)
            VALUES (?, ?, ?, ?, ?, ?)
            """, (id_counter, area_code, name, enName, officeName, region_code))
            id_counter += 1
    else:
        # 子エリアがいない場合
        cursor.execute("""
        INSERT INTO area_info (id, area_code, area_name, en_name, office_name, children_code)
        VALUES (?, ?, ?, ?, ?, ?)
        """, (id_counter, area_code, name, enName, officeName, 'N/A'))
        id_counter += 1

# コミットして変更を保存
conn.commit()

# データベース接続を閉じる
conn.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[2], line 48
#      45 if children:
#      46     for region_code in children:
#      47         # 子エリアIDを挿入
# ---> 48         cursor.execute("""
#      49         INSERT INTO area_info (id, area_code, area_name, en_name, office_name, children_code)
#      50         VALUES (?, ?, ?, ?, ?, ?)
#      51         """, (id_counter, area_code, name, enName, officeName, region_code))
#      52         id_counter += 1
#      53 else:
#      54     # 子エリアがいない場合
#
# IntegrityError: UNIQUE constraint failed: area_info.id

# %%
import sqlite3
import requests

# 新しいデータベースのパスと名前
db_filename = 'weather_areas.db'

# 新しいデータベースに接続（存在しない場合は作成されます）
con = sqlite3.connect(db_filename)
cur = con.cursor()

# area_info.dbからデータを取得して、weather_areas.dbに保存する準備
area_info_db = 'area_info.db'
con_area_info = sqlite3.connect(area_info_db)
cur_area_info = con_area_info.cursor()

# area_infoテーブルからデータを取得
sql_select = "SELECT * FROM area_info;"
cur_area_info.execute(sql_select)

# area_infoテーブルをweather_areas.dbにコピー（テーブルが存在しない場合は作成）
cur.execute("""
CREATE TABLE IF NOT EXISTS area_info (
    id INTEGER PRIMARY KEY,
    area_code TEXT,
    area_name TEXT,
    en_name TEXT,
    office_name TEXT,
    children_code TEXT
)
""")

# area_infoからデータを1行ずつ取得し、weather_areas.dbのarea_infoテーブルに挿入
for row in cur_area_info:
    id, area_code, area_name, en_name, office_name, children_code = row
    cur.execute("""
    INSERT INTO area_info (id, area_code, area_name, en_name, office_name, children_code)
    VALUES (?, ?, ?, ?, ?, ?)
    """, (id, area_code, area_name, en_name, office_name, children_code))

# weather_forecast_areasテーブルを作成
cur.execute("""
CREATE TABLE IF NOT EXISTS weather_forecast_areas (
    id INTEGER,
    children_code TEXT,
    area_name TEXT,
    area_code TEXT,
    date TEXT,
    weather_codes TEXT,
    weathers TEXT,
    winds TEXT,
    waves TEXT
)
""")

# area_info.dbから取得したデータを使って、weather_forecast_areasテーブルに予報データを挿入
for row in cur_area_info:
    id, area_code, area_name, en_name, office_name, children_code = row

    # children_codeを使ってURLを作成
    url = f"https://www.jma.go.jp/bosai/forecast/data/forecast/{children_code}.json"
    
    try:
        # URLからJSONデータを取得
        response = requests.get(url)
        response.raise_for_status()  # レスポンスが成功でない場合、例外を発生

        # JSONデータを解析
        data = response.json()

        # 時刻（timeDefines）の情報を取得
        time_defines = data[0]['timeSeries'][0]['timeDefines']
        
        # 各エリアの情報を取得
        areas = data[0]['timeSeries'][0]['areas']

        # 各エリアの情報をループ処理
        for area in areas:
            area_name = area['area']['name']
            area_code = area['area']['code']
            weather_codes = area.get('weatherCodes', ['なし'])
            weathers = area.get('weathers', ['なし'])
            winds = area.get('winds', ['なし'])
            waves = area.get('waves', ['なし'])

            # データを1行ずつDBに挿入
            for i in range(len(time_defines)):
                row_data = (
                    id,  # ID
                    children_code,  # Children Code
                    area_name,  # Area Name
                    area_code,  # Area Code
                    time_defines[i],  # Date
                    weather_codes[i] if i < len(weather_codes) else 'なし',  # Weather Codes
                    weathers[i] if i < len(weathers) else 'なし',  # Weathers
                    winds[i] if i < len(winds) else 'なし',  # Winds
                    waves[i] if i < len(waves) else 'なし'  # Waves
                )
                # DBにデータを挿入
                cur.execute("""
                INSERT INTO weather_forecast_areas (
                    id, children_code, area_name, area_code, date, weather_codes, weathers, winds, waves
                ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
                """, row_data)

    except requests.exceptions.RequestException as e:
        # リクエストエラーが発生した場合
        print(f"Error fetching data from URL {url}: {e}")

# コミットして変更を保存
con.commit()

# 作成されたテーブルの一覧を表示
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cur.fetchall()

print("作成されたテーブル一覧:")
for table in tables:
    table_name = table[0]
    if table_name in ["area_info", "weather_forecast_areas"]:
        print(f"テーブル名: {table_name}")
        
        # 各テーブルのデータを表示（最大10行のみ表示）
        cur.execute(f"SELECT * FROM {table_name} LIMIT 10;")
        rows = cur.fetchall()
        print(f"テーブル {table_name} のデータ:")
        for row in rows:
            print(row)
        print("-" * 50)

# DBへの接続を閉じる
con_area_info.close()
con.close()

print("データベースの作成とデータ挿入が完了しました。")
# Out:
# 作成されたテーブル一覧:
# テーブル名: area_info
# テーブル area_info のデータ:
# (1, '010100', '北海道地方', 'Hokkaido', '札幌管区気象台', '011000')
# (2, '010100', '北海道地方', 'Hokkaido', '札幌管区気象台', '012000')
# (3, '010100', '北海道地方', 'Hokkaido', '札幌管区気象台', '013000')
# (4, '010100', '北海道地方', 'Hokkaido', '札幌管区気象台', '014030')
# (5, '010100', '北海道地方', 'Hokkaido', '札幌管区気象台', '014100')
# (6, '010100', '北海道地方', 'Hokkaido', '札幌管区気象台', '015000')
# (7, '010100', '北海道地方', 'Hokkaido', '札幌管区気象台', '016000')
# (8, '010100', '北海道地方', 'Hokkaido', '札幌管区気象台', '017000')
# (9, '010200', '東北地方', 'Tohoku', '仙台管区気象台', '020000')
# (10, '010200', '東北地方', 'Tohoku', '仙台管区気象台', '030000')
# --------------------------------------------------
# テーブル名: weather_forecast_areas
# テーブル weather_forecast_areas のデータ:
# --------------------------------------------------
# データベースの作成とデータ挿入が完了しました。

# %%
import sqlite3

# データベースのパスと名前
db_filename = 'area_info.db'

# DBに接続
con = sqlite3.connect(db_filename)

# SQLを実行するためのカーソルオブジェクトを取得
cur = con.cursor()

# データを参照するSQL文
# 例: area_infoテーブルのすべてのデータを取得する
sql_select = "SELECT * FROM area_info;"

# SQLを実行
cur.execute(sql_select)

# データベースから取得したデータをループで表示
for row in cur:
    # 行データ(row)はタプルなので、アンパックして列データを取得
    id, area_code, area_name, en_name, office_name, children_code = row
    print(f"id: {id}, area_code: {area_code}, area_name: {area_name}, en_name: {en_name}, office_name: {office_name}, children_code: {children_code}")

# DBへの接続を閉じる
con.close()
# Out:
# id: 1, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 011000
# id: 2, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 012000
# id: 3, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 013000
# id: 4, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 014030
# id: 5, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 014100
# id: 6, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 015000
# id: 7, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 016000
# id: 8, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 017000
# id: 9, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 020000
# id: 10, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 030000
# id: 11, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 040000
# id: 12, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 050000
# id: 13, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 060000
# id: 14, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 070000
# id: 15, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 080000
# id: 16, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 090000
# id: 17, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 100000
# id: 18, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 110000
# id: 19, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 120000
# id: 20, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 130000
# id: 21, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 140000
# id: 22, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 190000
# id: 23, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 200000
# id: 24, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 210000
# id: 25, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 220000
# id: 26, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 230000
# id: 27, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 240000
# id: 28, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 150000
# id: 29, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 160000
# id: 30, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 170000
# id: 31, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 180000
# id: 32, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 250000
# id: 33, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 260000
# id: 34, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 270000
# id: 35, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 280000
# id: 36, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 290000
# id: 37, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 300000
# id: 38, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 310000
# id: 39, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 320000
# id: 40, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 330000
# id: 41, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 340000
# id: 42, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 360000
# id: 43, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 370000
# id: 44, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 380000
# id: 45, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 390000
# id: 46, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 350000
# id: 47, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 400000
# id: 48, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 410000
# id: 49, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 420000
# id: 50, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 430000
# id: 51, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 440000
# id: 52, area_code: 011000, area_name: 九州南部・奄美地方, en_name: Southern Kyushu and Amami, office_name: 鹿児島地方気象台, children_code: 450000
# id: 53, area_code: 011000, area_name: 九州南部・奄美地方, en_name: Southern Kyushu and Amami, office_name: 鹿児島地方気象台, children_code: 460040
# id: 54, area_code: 011000, area_name: 九州南部・奄美地方, en_name: Southern Kyushu and Amami, office_name: 鹿児島地方気象台, children_code: 460100
# id: 55, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 471000
# id: 56, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 472000
# id: 57, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 473000
# id: 58, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 474000

# %% [markdown]
# ##  地町村ごとの天気予報を取得する

# %%
import sqlite3
import requests

# データベースのパスと名前
db_filename = 'weather_forecast.db'

# 新しいデータベースに接続（存在しない場合は作成されます）
con = sqlite3.connect(db_filename)
cur = con.cursor()

# 既存のarea_info.dbからデータを取得
area_info_db = 'area_info.db'
con_area_info = sqlite3.connect(area_info_db)
cur_area_info = con_area_info.cursor()

# SQLを実行して、area_infoテーブルからデータを取得
sql_select = "SELECT * FROM area_info;"
cur_area_info.execute(sql_select)

# データベースから取得したデータをループで処理
for row in cur_area_info:
    # 行データ(row)はタプルなので、アンパックして列データを取得
    id, area_code, area_name, en_name, office_name, children_code = row
    print(f"id: {id}, area_code: {area_code}, area_name: {area_name}, en_name: {en_name}, office_name: {office_name}, children_code: {children_code}")

    # children_codeを使ってURLを作成
    url = f"https://www.jma.go.jp/bosai/forecast/data/forecast/{children_code}.json"
    
    try:
        # URLからJSONデータを取得
        response = requests.get(url)
        response.raise_for_status()  # レスポンスが成功でない場合、例外を発生

        # JSONデータを解析
        data = response.json()

        # 時刻（timeDefines）の情報を取得
        time_defines = data[0]['timeSeries'][0]['timeDefines']
        
        # 各エリアの情報を取得
        areas = data[0]['timeSeries'][0]['areas']  # ここでエリアのリストを取得

        # id と area_code 別のテーブル作成
        # テーブル名を "weather_forecast_areas_{area_code}_{id}" にする
        table_name = f"weather_forecast_areas_{area_code}_{id}"
        
        # 新しいテーブルを作成（area_codeとidをテーブル名にする）
        cur.execute(f"""
        CREATE TABLE IF NOT EXISTS "{table_name}" (
            id INTEGER,
            children_code TEXT,
            area_name TEXT,
            area_code TEXT,
            date TEXT,
            weather_codes TEXT,
            weathers TEXT,
            winds TEXT,
            waves TEXT
        )
        """)

        # 各エリアの情報をループ処理
        for area in areas:
            area_name = area['area']['name']
            area_code = area['area']['code']
            weather_codes = area.get('weatherCodes', ['なし'])
            weathers = area.get('weathers', ['なし'])
            winds = area.get('winds', ['なし'])
            waves = area.get('waves', ['なし'])

            # データを1行ずつDBに挿入
            for i in range(len(time_defines)):
                # 行データを準備
                row_data = (
                    id,  # ID
                    children_code,  # Children Code
                    area_name,  # Area Name
                    area_code,  # Area Code
                    time_defines[i],  # Date
                    weather_codes[i] if i < len(weather_codes) else 'なし',  # Weather Codes
                    weathers[i] if i < len(weathers) else 'なし',  # Weathers
                    winds[i] if i < len(winds) else 'なし',  # Winds
                    waves[i] if i < len(waves) else 'なし'  # Waves
                )
                # DBにデータを挿入（area_codeとidをテーブル名として使用）
                cur.execute(f"""
                INSERT INTO "{table_name}" (
                    id, children_code, area_name, area_code, date, weather_codes, weathers, winds, waves
                ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
                """, row_data)

    except requests.exceptions.RequestException as e:
        # リクエストエラーが発生した場合
        print(f"Error fetching data from URL {url}: {e}")

# コミットして変更を保存
con.commit()

# 作成されたテーブルの一覧を表示
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cur.fetchall()

print("作成されたテーブル一覧:")
for table in tables:
    table_name = table[0]
    if table_name.startswith("weather_forecast_areas_"):
        print(f"テーブル名: {table_name}")
        
        # 各テーブルのデータを表示（最大10行のみ表示）
        cur.execute(f"SELECT * FROM {table_name} LIMIT 10;")
        rows = cur.fetchall()
        print(f"テーブル {table_name} のデータ:")
        for row in rows:
            print(row)
        print("-" * 50)

# DBへの接続を閉じる
con_area_info.close()
con.close()

print("データベースの作成とデータ挿入が完了しました。")
# Out:
# id: 1, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 011000
# id: 2, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 012000
# id: 3, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 013000
# id: 4, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 014030
# Error fetching data from URL https://www.jma.go.jp/bosai/forecast/data/forecast/014030.json: 404 Client Error: Not Found for url: https://www.jma.go.jp/bosai/forecast/data/forecast/014030.json
# id: 5, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 014100
# id: 6, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 015000
# id: 7, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 016000
# id: 8, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 017000
# id: 9, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 020000
# id: 10, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 030000
# id: 11, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 040000
# id: 12, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 050000
# id: 13, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 060000
# id: 14, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 070000
# id: 15, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 080000
# id: 16, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 090000
# id: 17, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 100000
# id: 18, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 110000
# id: 19, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 120000
# id: 20, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 130000
# id: 21, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 140000
# id: 22, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 190000
# id: 23, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 200000
# id: 24, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 210000
# id: 25, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 220000
# id: 26, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 230000
# id: 27, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 240000
# id: 28, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 150000
# id: 29, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 160000
# id: 30, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 170000
# id: 31, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 180000
# id: 32, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 250000
# id: 33, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 260000
# id: 34, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 270000
# id: 35, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 280000
# id: 36, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 290000
# id: 37, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 300000
# id: 38, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 310000
# id: 39, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 320000
# id: 40, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 330000
# id: 41, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 340000
# id: 42, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 360000
# id: 43, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 370000
# id: 44, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 380000
# id: 45, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 390000
# id: 46, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 350000
# id: 47, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 400000
# id: 48, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 410000
# id: 49, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 420000
# id: 50, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 430000
# id: 51, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 440000
# id: 52, area_code: 011000, area_name: 九州南部・奄美地方, en_name: Southern Kyushu and Amami, office_name: 鹿児島地方気象台, children_code: 450000
# id: 53, area_code: 011000, area_name: 九州南部・奄美地方, en_name: Southern Kyushu and Amami, office_name: 鹿児島地方気象台, children_code: 460040
# Error fetching data from URL https://www.jma.go.jp/bosai/forecast/data/forecast/460040.json: 404 Client Error: Not Found for url: https://www.jma.go.jp/bosai/forecast/data/forecast/460040.json
# id: 54, area_code: 011000, area_name: 九州南部・奄美地方, en_name: Southern Kyushu and Amami, office_name: 鹿児島地方気象台, children_code: 460100
# id: 55, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 471000
# id: 56, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 472000
# id: 57, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 473000
# id: 58, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 474000
# 作成されたテーブル一覧:
# テーブル名: weather_forecast_areas_010100
# テーブル weather_forecast_areas_010100 のデータ:
# (1, '011000', '宗谷地方', '011000', '2024-12-04T17:00:00+09:00', '217', 'くもり\u3000夜\u3000雪\u3000で\u3000ふぶく\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く', '３メートル\u3000後\u3000２．５メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-05T00:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000夕方\u3000から\u3000時々\u3000くもり\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-06T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり', '北西の風\u3000後\u3000西の風', '２メートル\u3000後\u3000２．５メートル')
# (2, '012000', '上川地方', '012010', '2024-12-04T17:00:00+09:00', '402', '雪\u3000夜のはじめ頃\u3000くもり\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000南の風', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-05T00:00:00+09:00', '402', '雪\u3000夕方\u3000から\u3000時々\u3000くもり\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '南の風\u3000日中\u3000西の風', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-06T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり', '南西の風\u3000後\u3000西の風', 'なし')
# (2, '012000', '留萌地方', '012020', '2024-12-04T17:00:00+09:00', '400', '雪\u3000で\u3000ふぶく\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く', '３メートル\u3000後\u3000２．５メートル')
# (2, '012000', '留萌地方', '012020', '2024-12-05T00:00:00+09:00', '406', '雪\u3000で\u3000ふぶく\u3000夕方\u3000から\u3000時々\u3000くもり\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000日中\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (2, '012000', '留萌地方', '012020', '2024-12-06T00:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000時々\u3000くもり', '西の風\u3000やや強く', '２メートル\u3000後\u3000３メートル')
# (3, '013000', '網走地方', '013010', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ\u3000所により\u3000雪', '北西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200
# テーブル weather_forecast_areas_010200 のデータ:
# (9, '020000', '津軽', '020010', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '西の風\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000２メートル')
# (9, '020000', '津軽', '020010', '2024-12-05T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う', '西の風\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル\u3000後\u3000３メートル')
# (9, '020000', '津軽', '020010', '2024-12-06T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '西の風', '３メートル\u3000後\u3000４メートル')
# (9, '020000', '下北', '020020', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '西の風\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000強く', '１．５メートル')
# (9, '020000', '下北', '020020', '2024-12-05T00:00:00+09:00', '371', '雪か雨\u3000昼過ぎ\u3000から\u3000くもり\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う', '南の風\u3000後\u3000西の風\u3000海上\u3000では\u3000西の風\u3000強く', '１．５メートル\u3000後\u3000２メートル')
# (9, '020000', '下北', '020020', '2024-12-06T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '北西の風\u3000後\u3000西の風', '１メートル\u3000後\u3000２メートル')
# (9, '020000', '三八上北', '020030', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (9, '020000', '三八上北', '020030', '2024-12-05T00:00:00+09:00', '260', 'くもり\u3000明け方\u3000から\u3000朝\u3000雪か雨\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う', '南西の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '１メートル\u3000後\u3000１．５メートル')
# (9, '020000', '三八上北', '020030', '2024-12-06T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '西の風\u3000やや強く', '１メートル\u3000後\u3000２メートル')
# (10, '030000', '内陸', '030010', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '北の風\u3000後\u3000南東の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300
# テーブル weather_forecast_areas_010300 のデータ:
# (15, '080000', '北部', '080010', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり', '北西の風\u3000後\u3000北の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル')
# (15, '080000', '北部', '080010', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000２メートル')
# (15, '080000', '北部', '080010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '２メートル')
# (15, '080000', '南部', '080020', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり', '北東の風\u3000海上\u3000では\u3000北東の風\u3000やや強く', '２メートル')
# (15, '080000', '南部', '080020', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000２メートル')
# (15, '080000', '南部', '080020', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000後\u3000南西の風', '２メートル')
# (16, '090000', '南部', '090010', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北の風', 'なし')
# (16, '090000', '南部', '090010', '2024-12-05T00:00:00+09:00', '100', '晴れ', '北の風', 'なし')
# (16, '090000', '南部', '090010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '南西の風', 'なし')
# (16, '090000', '北部', '090020', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北西の風\u3000後\u3000北の風\u3000日光市\u3000では\u3000はじめ\u3000西の風\u3000やや強く', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010400
# テーブル weather_forecast_areas_010400 のデータ:
# (24, '210000', '美濃地方', '210010', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北西の風\u3000後\u3000西の風', 'なし')
# (24, '210000', '美濃地方', '210010', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000昼過ぎ\u3000まで\u3000時々\u3000晴れ\u3000所により\u3000夜\u3000雨か雪\u3000で\u3000雷を伴う', '北の風\u3000後\u3000西の風', 'なし')
# (24, '210000', '美濃地方', '210010', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風', 'なし')
# (24, '210000', '飛騨地方', '210020', '2024-12-04T17:00:00+09:00', '200', 'くもり', '北西の風\u3000後\u3000西の風', 'なし')
# (24, '210000', '飛騨地方', '210020', '2024-12-05T00:00:00+09:00', '281', 'くもり\u3000夜\u3000雪か雨\u3000飛騨北部\u3000では\u3000雷\u3000を伴う', '西の風', 'なし')
# (24, '210000', '飛騨地方', '210020', '2024-12-06T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '北の風', 'なし')
# (25, '220000', '中部', '220010', '2024-12-04T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '西の風\u3000やや強く\u3000海上\u3000では\u3000北西の風\u3000強く', '２．５メートル')
# (25, '220000', '中部', '220010', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000やや強く\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000２メートル')
# (25, '220000', '中部', '220010', '2024-12-06T00:00:00+09:00', '100', '晴れ', '西の風\u3000やや強く', '２メートル')
# (25, '220000', '西部', '220040', '2024-12-04T17:00:00+09:00', '100', '晴れ', '西の風\u3000やや強く\u3000海上\u3000では\u3000北西の風\u3000強く', '２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010500
# テーブル weather_forecast_areas_010500 のデータ:
# (28, '150000', '下越', '150010', '2024-12-04T17:00:00+09:00', '300', '雨\u3000所により\u3000夜遅く\u3000雷\u3000を伴う', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル\u3000うねり\u3000を伴う')
# (28, '150000', '下越', '150010', '2024-12-05T00:00:00+09:00', '300', '雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (28, '150000', '下越', '150010', '2024-12-06T00:00:00+09:00', '302', '雨\u3000時々\u3000くもり', '西の風\u3000強く\u3000後\u3000やや強く', '３メートル\u3000後\u3000４メートル')
# (28, '150000', '中越', '150020', '2024-12-04T17:00:00+09:00', '300', '雨\u3000所により\u3000夜遅く\u3000雷\u3000を伴う', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル\u3000うねり\u3000を伴う')
# (28, '150000', '中越', '150020', '2024-12-05T00:00:00+09:00', '300', '雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (28, '150000', '中越', '150020', '2024-12-06T00:00:00+09:00', '302', '雨\u3000時々\u3000くもり', '西の風\u3000やや強く', '３メートル\u3000後\u3000４メートル')
# (28, '150000', '上越', '150030', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨\u3000で\u3000雷を伴う', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル\u3000うねり\u3000を伴う')
# (28, '150000', '上越', '150030', '2024-12-05T00:00:00+09:00', '203', 'くもり\u3000時々\u3000雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (28, '150000', '上越', '150030', '2024-12-06T00:00:00+09:00', '302', '雨\u3000時々\u3000くもり', '西の風\u3000やや強く', '３メートル\u3000後\u3000４メートル')
# (28, '150000', '佐渡', '150040', '2024-12-04T17:00:00+09:00', '300', '雨\u3000所により\u3000夜遅く\u3000雷\u3000を伴う', '西の風\u3000やや強く', '３メートル\u3000後\u3000２．５メートル\u3000うねり\u3000を伴う')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010600
# テーブル weather_forecast_areas_010600 のデータ:
# (32, '250000', '南部', '250010', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '北西の風\u3000琵琶湖\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', 'なし')
# (32, '250000', '南部', '250010', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', 'なし')
# (32, '250000', '南部', '250010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北西の風', 'なし')
# (32, '250000', '北部', '250020', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '北西の風\u3000琵琶湖\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', 'なし')
# (32, '250000', '北部', '250020', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨\u3000で\u3000雷を伴う', '北西の風', 'なし')
# (32, '250000', '北部', '250020', '2024-12-06T00:00:00+09:00', '200', 'くもり', '北西の風', 'なし')
# (33, '260000', '南部', '260010', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '北西の風', 'なし')
# (33, '260000', '南部', '260010', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', 'なし')
# (33, '260000', '南部', '260010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', 'なし')
# (33, '260000', '北部', '260020', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２．５メートル\u3000うねり\u3000を伴う')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010700
# テーブル weather_forecast_areas_010700 のデータ:
# (38, '310000', '東部', '310010', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '西の風\u3000後\u3000南西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２．５メートル')
# (38, '310000', '東部', '310010', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000昼前\u3000から\u3000雨\u3000で\u3000雷を伴う', '南西の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (38, '310000', '東部', '310010', '2024-12-06T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '西の風\u3000やや強く', '３メートル')
# (38, '310000', '中・西部', '310020', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '西の風\u3000後\u3000南西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２．５メートル')
# (38, '310000', '中・西部', '310020', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000昼前\u3000から\u3000雨\u3000で\u3000雷を伴う', '南西の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (38, '310000', '中・西部', '310020', '2024-12-06T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '西の風\u3000やや強く', '３メートル')
# (39, '320000', '東部', '320010', '2024-12-04T17:00:00+09:00', '200', 'くもり', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル')
# (39, '320000', '東部', '320010', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000昼前\u3000から\u3000雨\u3000で\u3000雷を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (39, '320000', '東部', '320010', '2024-12-06T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '西の風\u3000やや強く', '３メートル')
# (39, '320000', '西部', '320020', '2024-12-04T17:00:00+09:00', '200', 'くもり', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010800
# テーブル weather_forecast_areas_010800 のデータ:
# (42, '360000', '北部', '360010', '2024-12-04T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (42, '360000', '北部', '360010', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (42, '360000', '北部', '360010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル')
# (42, '360000', '南部', '360020', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000やや強く\u3000後\u3000北西の風\u3000やや強く', '１．５メートル')
# (42, '360000', '南部', '360020', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北西の風\u3000やや強く', '１．５メートル')
# (42, '360000', '南部', '360020', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '１．５メートル')
# (43, '370000', '香川県', '370000', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '０．５メートル\u3000後\u3000１メートル')
# (43, '370000', '香川県', '370000', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (43, '370000', '香川県', '370000', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル')
# (44, '380000', '中予', '380010', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '北西の風', '０．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900
# テーブル weather_forecast_areas_010900 のデータ:
# (46, '350000', '西部', '350010', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜遅く\u3000雨', '北西の風\u3000下関\u3000では\u3000北西の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000０．５メートル')
# (46, '350000', '西部', '350010', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '北西の風\u3000後\u3000西の風\u3000やや強く', '２．５メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000１メートル')
# (46, '350000', '西部', '350010', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風', '２メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000１メートル')
# (46, '350000', '中部', '350020', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜遅く\u3000雨か雪', '北西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '０．５メートル')
# (46, '350000', '中部', '350020', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000雨', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (46, '350000', '中部', '350020', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル')
# (46, '350000', '東部', '350030', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ\u3000所により\u3000夜遅く\u3000雨か雪', '西の風\u3000柳井・光\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (46, '350000', '東部', '350030', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり\u3000所により\u3000雨', '西の風\u3000柳井・光\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (46, '350000', '東部', '350030', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '１メートル')
# (46, '350000', '北部', '350040', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜遅く\u3000雨', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011000
# テーブル weather_forecast_areas_011000 のデータ:
# (52, '450000', '南部平野部', '450010', '2024-12-04T17:00:00+09:00', '100', '晴れ', '西の風\u3000海上\u3000では\u3000北の風\u3000やや強く', '１．５メートル')
# (52, '450000', '南部平野部', '450010', '2024-12-05T00:00:00+09:00', '100', '晴れ\u3000昼前\u3000から\u3000昼過ぎ\u3000くもり', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000１メートル')
# (52, '450000', '南部平野部', '450010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '１メートル')
# (52, '450000', '北部平野部', '450020', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000後\u3000西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル')
# (52, '450000', '北部平野部', '450020', '2024-12-05T00:00:00+09:00', '100', '晴れ\u3000朝\u3000から\u3000昼前\u3000くもり', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000１メートル')
# (52, '450000', '北部平野部', '450020', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '１メートル')
# (52, '450000', '南部山沿い', '450030', '2024-12-04T17:00:00+09:00', '100', '晴れ', '西の風', 'なし')
# (52, '450000', '南部山沿い', '450030', '2024-12-05T00:00:00+09:00', '110', '晴れ\u3000昼前\u3000から\u3000時々\u3000くもり', '西の風', 'なし')
# (52, '450000', '南部山沿い', '450030', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', 'なし')
# (52, '450000', '北部山沿い', '450040', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011100
# テーブル weather_forecast_areas_011100 のデータ:
# (55, '471000', '本島中南部', '471010', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北東の風\u3000やや強く', '２メートル')
# (55, '471000', '本島中南部', '471010', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000朝晩\u3000晴れ', '北東の風', '２メートル\u3000後\u3000１．５メートル')
# (55, '471000', '本島中南部', '471010', '2024-12-06T00:00:00+09:00', '200', 'くもり', '北東の風', '１．５メートル')
# (55, '471000', '本島北部', '471020', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北東の風\u3000やや強く', '２メートル')
# (55, '471000', '本島北部', '471020', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000朝晩\u3000晴れ', '北東の風', '２メートル\u3000後\u3000１．５メートル')
# (55, '471000', '本島北部', '471020', '2024-12-06T00:00:00+09:00', '200', 'くもり', '北東の風', '１．５メートル')
# (55, '471000', '久米島', '471030', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北東の風\u3000やや強く', '２メートル')
# (55, '471000', '久米島', '471030', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000昼前\u3000まで\u3000時々\u3000晴れ', '北東の風', '２メートル\u3000後\u3000１．５メートル')
# (55, '471000', '久米島', '471030', '2024-12-06T00:00:00+09:00', '200', 'くもり', '北東の風', '１．５メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000やや強く', '２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_1
# テーブル weather_forecast_areas_010100_1 のデータ:
# (1, '011000', '宗谷地方', '011000', '2024-12-04T17:00:00+09:00', '217', 'くもり\u3000夜\u3000雪\u3000で\u3000ふぶく\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く', '３メートル\u3000後\u3000２．５メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-05T00:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000夕方\u3000から\u3000時々\u3000くもり\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-06T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり', '北西の風\u3000後\u3000西の風', '２メートル\u3000後\u3000２．５メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-05T17:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000夜のはじめ頃\u3000くもり', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-06T00:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000時々\u3000くもり\u3000所により\u3000朝\u3000から\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-07T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪\u3000で\u3000ふぶく', '北西の風\u3000やや強く\u3000後\u3000西の風\u3000やや強く', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_2
# テーブル weather_forecast_areas_010100_2 のデータ:
# (2, '012000', '上川地方', '012010', '2024-12-04T17:00:00+09:00', '402', '雪\u3000夜のはじめ頃\u3000くもり\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000南の風', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-05T00:00:00+09:00', '402', '雪\u3000夕方\u3000から\u3000時々\u3000くもり\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '南の風\u3000日中\u3000西の風', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-06T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり', '南西の風\u3000後\u3000西の風', 'なし')
# (2, '012000', '留萌地方', '012020', '2024-12-04T17:00:00+09:00', '400', '雪\u3000で\u3000ふぶく\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く', '３メートル\u3000後\u3000２．５メートル')
# (2, '012000', '留萌地方', '012020', '2024-12-05T00:00:00+09:00', '406', '雪\u3000で\u3000ふぶく\u3000夕方\u3000から\u3000時々\u3000くもり\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000日中\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (2, '012000', '留萌地方', '012020', '2024-12-06T00:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000時々\u3000くもり', '西の風\u3000やや強く', '２メートル\u3000後\u3000３メートル')
# (2, '012000', '上川地方', '012010', '2024-12-05T17:00:00+09:00', '413', '雪\u3000夜遅く\u3000くもり', '西の風\u3000後\u3000南の風', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-06T00:00:00+09:00', '402', '雪\u3000昼前\u3000まで\u3000時々\u3000くもり\u3000所により\u3000朝\u3000から\u3000雷\u3000を伴う', '南東の風\u3000後\u3000西の風', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-07T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり', '西の風', 'なし')
# (2, '012000', '留萌地方', '012020', '2024-12-05T17:00:00+09:00', '413', '雪\u3000で\u3000ふぶく\u3000夜遅く\u3000くもり', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_3
# テーブル weather_forecast_areas_010100_3 のデータ:
# (3, '013000', '網走地方', '013010', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ\u3000所により\u3000雪', '北西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１．５メートル')
# (3, '013000', '網走地方', '013010', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雪', '南の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '１．５メートル\u3000後\u3000２．５メートル')
# (3, '013000', '網走地方', '013010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '南西の風\u3000後\u3000北西の風', '２メートル')
# (3, '013000', '北見地方', '013020', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ\u3000所により\u3000雪', '北西の風\u3000後\u3000南西の風', 'なし')
# (3, '013000', '北見地方', '013020', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000昼前\u3000から\u3000昼過ぎ\u3000雪', '南西の風\u3000後\u3000南の風\u3000やや強く', 'なし')
# (3, '013000', '北見地方', '013020', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '南西の風\u3000後\u3000西の風', 'なし')
# (3, '013000', '紋別地方', '013030', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１．５メートル')
# (3, '013000', '紋別地方', '013030', '2024-12-05T00:00:00+09:00', '205', 'くもり\u3000昼過ぎ\u3000まで\u3000時々\u3000雪', '南西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル\u3000後\u3000２メートル')
# (3, '013000', '紋別地方', '013030', '2024-12-06T00:00:00+09:00', '204', 'くもり\u3000一時\u3000雪', '南西の風\u3000後\u3000西の風', '１．５メートル')
# (3, '013000', '網走地方', '013010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり\u3000所により\u3000夕方\u3000雪', '南の風\u3000後\u3000西の風\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル\u3000後\u3000２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_5
# テーブル weather_forecast_areas_010100_5 のデータ:
# (5, '014100', '釧路地方', '014020', '2024-12-04T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル\u3000後\u3000１．５メートル')
# (5, '014100', '釧路地方', '014020', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000昼過ぎ\u3000まで\u3000時々\u3000くもり\u3000所により\u3000昼前\u3000から\u3000昼過ぎ\u3000雪か雨', '西の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000南西の風\u3000強く', '１．５メートル\u3000後\u3000２．５メートル')
# (5, '014100', '釧路地方', '014020', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000後\u3000やや強く', '２メートル')
# (5, '014100', '根室地方', '014010', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１．５メートル')
# (5, '014100', '根室地方', '014010', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000昼過ぎ\u3000まで\u3000時々\u3000くもり\u3000所により\u3000昼前\u3000から\u3000昼過ぎ\u3000雪か雨', '西の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000南西の風\u3000強く', '１．５メートル\u3000後\u3000２．５メートル')
# (5, '014100', '根室地方', '014010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '２メートル')
# (5, '014100', '十勝地方', '014030', '2024-12-04T17:00:00+09:00', '100', '晴れ', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１．５メートル')
# (5, '014100', '十勝地方', '014030', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000昼過ぎ\u3000まで\u3000時々\u3000くもり\u3000所により\u3000朝\u3000から\u3000昼前\u3000雪', '西の風\u3000日中\u3000やや強く', '１．５メートル\u3000後\u3000２メートル')
# (5, '014100', '十勝地方', '014030', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北東の風\u3000後\u3000北西の風', '２メートル')
# (5, '014100', '釧路地方', '014020', '2024-12-05T17:00:00+09:00', '100', '晴れ', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000２メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_6
# テーブル weather_forecast_areas_010100_6 のデータ:
# (6, '015000', '胆振地方', '015010', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ\u3000所により\u3000雪', '西の風\u3000やや強く', '１．５メートル')
# (6, '015000', '胆振地方', '015010', '2024-12-05T00:00:00+09:00', '204', 'くもり\u3000明け方\u3000から\u3000朝\u3000雪\u3000で\u3000ふぶく\u3000所により\u3000明け方\u3000から\u3000昼前\u3000雷\u3000を伴う', '西の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '１．５メートル\u3000後\u3000２メートル')
# (6, '015000', '胆振地方', '015010', '2024-12-06T00:00:00+09:00', '204', 'くもり\u3000一時\u3000雪', '北の風\u3000後\u3000西の風', '１メートル\u3000後\u3000１．５メートル')
# (6, '015000', '日高地方', '015020', '2024-12-04T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雪', '西の風\u3000やや強く', '２メートル')
# (6, '015000', '日高地方', '015020', '2024-12-05T00:00:00+09:00', '413', '雪\u3000で\u3000ふぶく\u3000昼過ぎ\u3000から\u3000くもり\u3000所により\u3000明け方\u3000から\u3000昼前\u3000雷\u3000を伴う', '西の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル\u3000後\u3000２．５メートル')
# (6, '015000', '日高地方', '015020', '2024-12-06T00:00:00+09:00', '204', 'くもり\u3000一時\u3000雪', '西の風\u3000後\u3000北西の風', '２メートル\u3000後\u3000２．５メートル')
# (6, '015000', '胆振地方', '015010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雪', '西の風\u3000やや強く', '２メートル\u3000後\u3000１メートル')
# (6, '015000', '胆振地方', '015010', '2024-12-06T00:00:00+09:00', '216', 'くもり\u3000昼前\u3000から\u3000時々\u3000雪\u3000で\u3000ふぶく\u3000所により\u3000夕方\u3000から\u3000雷\u3000を伴う', '北の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '１メートル\u3000後\u3000２．５メートル')
# (6, '015000', '胆振地方', '015010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000やや強く\u3000後\u3000西の風\u3000やや強く', '２メートル')
# (6, '015000', '日高地方', '015020', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雪', '西の風\u3000やや強く\u3000日高東部\u3000では\u3000西の風\u3000強く', '２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_7
# テーブル weather_forecast_areas_010100_7 のデータ:
# (7, '016000', '石狩地方', '016010', '2024-12-04T17:00:00+09:00', '413', '雪\u3000夜\u3000くもり\u3000所により\u3000雷\u3000を伴う', '北西の風\u3000後\u3000南の風\u3000石狩北部\u3000では\u3000西の風\u3000やや強く', '２．５メートル')
# (7, '016000', '石狩地方', '016010', '2024-12-05T00:00:00+09:00', '205', 'くもり\u3000昼過ぎ\u3000まで\u3000時々\u3000雪\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '南の風\u3000後\u3000北西の風\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (7, '016000', '石狩地方', '016010', '2024-12-06T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪', '西の風\u3000後\u3000北西の風', '２メートル\u3000後\u3000３メートル')
# (7, '016000', '空知地方', '016020', '2024-12-04T17:00:00+09:00', '402', '雪\u3000夜のはじめ頃\u3000くもり\u3000所により\u3000雷\u3000を伴う', '北西の風\u3000後\u3000南の風', 'なし')
# (7, '016000', '空知地方', '016020', '2024-12-05T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '南の風\u3000後\u3000西の風', 'なし')
# (7, '016000', '空知地方', '016020', '2024-12-06T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり', '南東の風\u3000後\u3000北西の風', 'なし')
# (7, '016000', '後志地方', '016030', '2024-12-04T17:00:00+09:00', '402', '雪\u3000夜のはじめ頃\u3000くもり\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後志北部\u3000では\u3000西の風\u3000やや強く', '２．５メートル')
# (7, '016000', '後志地方', '016030', '2024-12-05T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '西の風\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (7, '016000', '後志地方', '016030', '2024-12-06T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり', '西の風\u3000後\u3000北西の風', '２メートル\u3000後\u3000３メートル')
# (7, '016000', '石狩地方', '016010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪\u3000で\u3000ふぶく', '北西の風\u3000後\u3000西の風\u3000石狩北部\u3000では\u3000西の風\u3000やや強く', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_8
# テーブル weather_forecast_areas_010100_8 のデータ:
# (8, '017000', '渡島地方', '017010', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ\u3000所により\u3000夜遅く\u3000雪\u3000で\u3000雷を伴う', '西の風\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000２メートル')
# (8, '017000', '渡島地方', '017010', '2024-12-05T00:00:00+09:00', '260', 'くもり\u3000明け方\u3000から\u3000朝\u3000雪か雨\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う', '西の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル\u3000後\u3000３メートル')
# (8, '017000', '渡島地方', '017010', '2024-12-06T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり', '西の風', '２．５メートル\u3000後\u3000４メートル')
# (8, '017000', '檜山地方', '017020', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪\u3000で\u3000雷を伴う', '西の風\u3000やや強く\u3000檜山奥尻島\u3000では\u3000西の風\u3000強く', '２．５メートル')
# (8, '017000', '檜山地方', '017020', '2024-12-05T00:00:00+09:00', '260', 'くもり\u3000明け方\u3000から\u3000朝\u3000雪か雨\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000檜山奥尻島\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (8, '017000', '檜山地方', '017020', '2024-12-06T00:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000時々\u3000くもり', '北西の風\u3000やや強く', '２．５メートル\u3000後\u3000３メートル')
# (8, '017000', '渡島地方', '017010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雪', '西の風\u3000やや強く\u3000後\u3000北西の風\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000強く', '３メートル')
# (8, '017000', '渡島地方', '017010', '2024-12-06T00:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000昼過ぎ\u3000まで\u3000時々\u3000くもり\u3000所により\u3000朝\u3000から\u3000雷\u3000を伴う', '北西の風\u3000後\u3000西の風\u3000やや強く\u3000渡島西部\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000５メートル')
# (8, '017000', '渡島地方', '017010', '2024-12-07T00:00:00+09:00', '204', 'くもり\u3000一時\u3000雪\u3000で\u3000ふぶく', '北西の風\u3000やや強く\u3000後\u3000西の風', '５メートル\u3000後\u3000３メートル')
# (8, '017000', '檜山地方', '017020', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雪', '西の風\u3000やや強く\u3000後\u3000北西の風\u3000やや強く\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000強く', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_9
# テーブル weather_forecast_areas_010200_9 のデータ:
# (9, '020000', '津軽', '020010', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '西の風\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000２メートル')
# (9, '020000', '津軽', '020010', '2024-12-05T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う', '西の風\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル\u3000後\u3000３メートル')
# (9, '020000', '津軽', '020010', '2024-12-06T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '西の風', '３メートル\u3000後\u3000４メートル')
# (9, '020000', '下北', '020020', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '西の風\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000強く', '１．５メートル')
# (9, '020000', '下北', '020020', '2024-12-05T00:00:00+09:00', '371', '雪か雨\u3000昼過ぎ\u3000から\u3000くもり\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う', '南の風\u3000後\u3000西の風\u3000海上\u3000では\u3000西の風\u3000強く', '１．５メートル\u3000後\u3000２メートル')
# (9, '020000', '下北', '020020', '2024-12-06T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '北西の風\u3000後\u3000西の風', '１メートル\u3000後\u3000２メートル')
# (9, '020000', '三八上北', '020030', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (9, '020000', '三八上北', '020030', '2024-12-05T00:00:00+09:00', '260', 'くもり\u3000明け方\u3000から\u3000朝\u3000雪か雨\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う', '南西の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '１メートル\u3000後\u3000１．５メートル')
# (9, '020000', '三八上北', '020030', '2024-12-06T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '西の風\u3000やや強く', '１メートル\u3000後\u3000２メートル')
# (9, '020000', '津軽', '020010', '2024-12-05T17:00:00+09:00', '281', 'くもり\u3000夜遅く\u3000雪か雨', '西の風\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000強く', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_10
# テーブル weather_forecast_areas_010200_10 のデータ:
# (10, '030000', '内陸', '030010', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '北の風\u3000後\u3000南東の風', 'なし')
# (10, '030000', '内陸', '030010', '2024-12-05T00:00:00+09:00', '371', '雪か雨\u3000昼前\u3000から\u3000くもり', '南の風\u3000日中\u3000西の風', 'なし')
# (10, '030000', '内陸', '030010', '2024-12-06T00:00:00+09:00', '260', 'くもり\u3000一時\u3000雪か雨', '南の風\u3000後\u3000西の風', 'なし')
# (10, '030000', '沿岸北部', '030020', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '北の風\u3000後\u3000西の風\u3000海上\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000１メートル')
# (10, '030000', '沿岸北部', '030020', '2024-12-05T00:00:00+09:00', '210', 'くもり\u3000昼前\u3000から\u3000時々\u3000晴れ\u3000所により\u3000昼前\u3000まで\u3000雪か雨', '南西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000南西の風\u3000やや強く', '１メートル\u3000後\u3000１．５メートル')
# (10, '030000', '沿岸北部', '030020', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル\u3000後\u3000２メートル')
# (10, '030000', '沿岸南部', '030030', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北西の風\u3000海上\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000１メートル')
# (10, '030000', '沿岸南部', '030030', '2024-12-05T00:00:00+09:00', '210', 'くもり\u3000昼過ぎ\u3000から\u3000時々\u3000晴れ\u3000所により\u3000昼前\u3000まで\u3000雨か雪', '北の風\u3000海上\u3000では\u3000南西の風\u3000やや強く', '１メートル\u3000後\u3000１．５メートル')
# (10, '030000', '沿岸南部', '030030', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル\u3000後\u3000２メートル')
# (10, '030000', '内陸', '030010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '東の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_11
# テーブル weather_forecast_areas_010200_11 のデータ:
# (11, '040000', '東部', '040010', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり\u3000所により\u3000夜遅く\u3000雨', '北西の風\u3000後\u3000北の風\u3000海上\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000１メートル')
# (11, '040000', '東部', '040010', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '北の風\u3000後\u3000西の風\u3000やや強く', '１メートル\u3000後\u3000１．５メートル')
# (11, '040000', '東部', '040010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000後\u3000やや強く', '１メートル\u3000後\u3000２メートル')
# (11, '040000', '西部', '040020', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜遅く\u3000雨か雪', '西の風', 'なし')
# (11, '040000', '西部', '040020', '2024-12-05T00:00:00+09:00', '207', 'くもり\u3000朝晩\u3000雨か雪', '南西の風', 'なし')
# (11, '040000', '西部', '040020', '2024-12-06T00:00:00+09:00', '206', 'くもり\u3000一時\u3000雨か雪', '西の風', 'なし')
# (11, '040000', '東部', '040010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雨か雪', '西の風\u3000後\u3000北の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (11, '040000', '東部', '040010', '2024-12-06T00:00:00+09:00', '102', '晴れ\u3000時々\u3000くもり\u3000昼前\u3000一時\u3000雨', '南西の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000南西の風\u3000強く', '１メートル\u3000後\u3000２メートル')
# (11, '040000', '東部', '040010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000やや強く', '１．５メートル')
# (11, '040000', '西部', '040020', '2024-12-05T17:00:00+09:00', '317', '雨か雪\u3000夜遅く\u3000くもり', '西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_12
# テーブル weather_forecast_areas_010200_12 のデータ:
# (12, '050000', '沿岸', '050010', '2024-12-04T17:00:00+09:00', '281', 'くもり\u3000夜遅く\u3000雪か雨', '西の風\u3000後\u3000北の風\u3000海上\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル')
# (12, '050000', '沿岸', '050010', '2024-12-05T00:00:00+09:00', '304', '雨か雪\u3000所により\u3000雷\u3000を伴う', '東の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル\u3000後\u3000３メートル')
# (12, '050000', '沿岸', '050010', '2024-12-06T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '西の風\u3000やや強く', '３メートル\u3000後\u3000５メートル')
# (12, '050000', '内陸', '050020', '2024-12-04T17:00:00+09:00', '281', 'くもり\u3000夜遅く\u3000雪か雨', '北西の風\u3000後\u3000西の風', 'なし')
# (12, '050000', '内陸', '050020', '2024-12-05T00:00:00+09:00', '340', '雪か雨\u3000所により\u3000雷\u3000を伴う', '北西の風\u3000後\u3000西の風', 'なし')
# (12, '050000', '内陸', '050020', '2024-12-06T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '西の風\u3000やや強く', 'なし')
# (12, '050000', '沿岸', '050010', '2024-12-05T17:00:00+09:00', '340', '雪か雨\u3000所により\u3000雷\u3000を伴う', '北西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '３メートル')
# (12, '050000', '沿岸', '050010', '2024-12-06T00:00:00+09:00', '406', '雪か雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000強く\u3000海上\u3000では\u3000西の風\u3000非常に強く', '３メートル\u3000後\u3000５メートル')
# (12, '050000', '沿岸', '050010', '2024-12-07T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪\u3000で\u3000ふぶく', '西の風\u3000やや強く', '４メートル\u3000後\u3000３メートル')
# (12, '050000', '内陸', '050020', '2024-12-05T17:00:00+09:00', '340', '雪か雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000北の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_13
# テーブル weather_forecast_areas_010200_13 のデータ:
# (13, '060000', '村山', '060010', '2024-12-04T17:00:00+09:00', '300', '雨', '南の風', 'なし')
# (13, '060000', '村山', '060010', '2024-12-05T00:00:00+09:00', '302', '雨\u3000朝晩\u3000くもり\u3000所により\u3000雷\u3000を伴う', '南の風', 'なし')
# (13, '060000', '村山', '060010', '2024-12-06T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '南の風\u3000後\u3000南西の風', 'なし')
# (13, '060000', '置賜', '060020', '2024-12-04T17:00:00+09:00', '300', '雨', '西の風\u3000後\u3000南の風', 'なし')
# (13, '060000', '置賜', '060020', '2024-12-05T00:00:00+09:00', '300', '雨\u3000所により\u3000雷\u3000を伴う', '西の風', 'なし')
# (13, '060000', '置賜', '060020', '2024-12-06T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '西の風', 'なし')
# (13, '060000', '庄内', '060030', '2024-12-04T17:00:00+09:00', '300', '雨', '北西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル')
# (13, '060000', '庄内', '060030', '2024-12-05T00:00:00+09:00', '300', '雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル\u3000後\u3000３メートル')
# (13, '060000', '庄内', '060030', '2024-12-06T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '西の風\u3000やや強く\u3000後\u3000北西の風\u3000やや強く', '３メートル\u3000後\u3000５メートル')
# (13, '060000', '最上', '060040', '2024-12-04T17:00:00+09:00', '300', '雨', '北西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_14
# テーブル weather_forecast_areas_010200_14 のデータ:
# (14, '070000', '中通り', '070010', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北西の風', 'なし')
# (14, '070000', '中通り', '070010', '2024-12-05T00:00:00+09:00', '110', '晴れ\u3000昼前\u3000から\u3000時々\u3000くもり\u3000所により\u3000雨か雪', '西の風', 'なし')
# (14, '070000', '中通り', '070010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '南の風\u3000後\u3000西の風', 'なし')
# (14, '070000', '浜通り', '070020', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北西の風\u3000後\u3000北の風\u3000海上\u3000では\u3000北の風\u3000やや強く', '１．５メートル')
# (14, '070000', '浜通り', '070020', '2024-12-05T00:00:00+09:00', '110', '晴れ\u3000昼前\u3000から\u3000時々\u3000くもり', '北西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (14, '070000', '浜通り', '070020', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１．５メートル')
# (14, '070000', '会津', '070030', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風', 'なし')
# (14, '070000', '会津', '070030', '2024-12-05T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '西の風', 'なし')
# (14, '070000', '会津', '070030', '2024-12-06T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '西の風', 'なし')
# (14, '070000', '中通り', '070010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨か雪', '西の風\u3000後\u3000南西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_15
# テーブル weather_forecast_areas_010300_15 のデータ:
# (15, '080000', '北部', '080010', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり', '北西の風\u3000後\u3000北の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル')
# (15, '080000', '北部', '080010', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000２メートル')
# (15, '080000', '北部', '080010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '２メートル')
# (15, '080000', '南部', '080020', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり', '北東の風\u3000海上\u3000では\u3000北東の風\u3000やや強く', '２メートル')
# (15, '080000', '南部', '080020', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000２メートル')
# (15, '080000', '南部', '080020', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000後\u3000南西の風', '２メートル')
# (15, '080000', '北部', '080010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル')
# (15, '080000', '北部', '080010', '2024-12-06T00:00:00+09:00', '110', '晴れ\u3000昼過ぎ\u3000から\u3000時々\u3000くもり', '西の風\u3000後\u3000南西の風\u3000やや強く\u3000海上\u3000では\u3000南西の風\u3000強く', '２メートル\u3000後\u3000２．５メートル')
# (15, '080000', '北部', '080010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風', '２メートル\u3000後\u3000１．５メートル')
# (15, '080000', '南部', '080020', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_16
# テーブル weather_forecast_areas_010300_16 のデータ:
# (16, '090000', '南部', '090010', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北の風', 'なし')
# (16, '090000', '南部', '090010', '2024-12-05T00:00:00+09:00', '100', '晴れ', '北の風', 'なし')
# (16, '090000', '南部', '090010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '南西の風', 'なし')
# ...
# (46, '350000', '中部', '350020', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000雨', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (46, '350000', '中部', '350020', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル')
# (46, '350000', '東部', '350030', '2024-12-04T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ\u3000所により\u3000夜遅く\u3000雨か雪', '西の風\u3000柳井・光\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (46, '350000', '東部', '350030', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり\u3000所により\u3000雨', '西の風\u3000柳井・光\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (46, '350000', '東部', '350030', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '１メートル')
# (46, '350000', '北部', '350040', '2024-12-04T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜遅く\u3000雨', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_47
# テーブル weather_forecast_areas_010900_47 のデータ:
# (47, '400000', '福岡地方', '400010', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり\u3000所により\u3000夜遅く\u3000雨', '北の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル')
# (47, '400000', '福岡地方', '400010', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '北の風\u3000後\u3000西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２メートル')
# (47, '400000', '福岡地方', '400010', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風', '２メートル')
# (47, '400000', '北九州地方', '400020', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり\u3000所により\u3000夜遅く\u3000雨', '北西の風\u3000後\u3000西の風\u3000北九州・遠賀地区\u3000では\u3000北西の風\u3000やや強く', '２メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000０．５メートル')
# (47, '400000', '北九州地方', '400020', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000１メートル')
# (47, '400000', '北九州地方', '400020', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風', '２メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000１メートル')
# (47, '400000', '筑豊地方', '400030', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり\u3000所により\u3000夜遅く\u3000雨', '北の風\u3000後\u3000南の風', 'なし')
# (47, '400000', '筑豊地方', '400030', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '北西の風\u3000後\u3000西の風', 'なし')
# (47, '400000', '筑豊地方', '400030', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風', 'なし')
# (47, '400000', '筑後地方', '400040', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北の風\u3000後\u3000南の風', '０．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_48
# テーブル weather_forecast_areas_010900_48 のデータ:
# (48, '410000', '南部', '410010', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北の風\u3000後\u3000西の風', '０．５メートル')
# (48, '410000', '南部', '410010', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000明け方\u3000から\u3000朝\u3000雨', '西の風', '０．５メートル')
# (48, '410000', '南部', '410010', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風', '０．５メートル')
# (48, '410000', '北部', '410020', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり', '北西の風\u3000後\u3000南東の風', '１．５メートル')
# (48, '410000', '北部', '410020', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000朝\u3000まで\u3000雨', '北西の風\u3000後\u3000西の風\u3000唐津地区\u3000では\u3000西の風\u3000やや強く', '１．５メートル\u3000後\u3000２メートル')
# (48, '410000', '北部', '410020', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風', '１．５メートル')
# (48, '410000', '南部', '410010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雨', '西の風\u3000後\u3000南西の風', '０．５メートル')
# (48, '410000', '南部', '410010', '2024-12-06T00:00:00+09:00', '200', 'くもり\u3000夜\u3000晴れ\u3000所により\u3000明け方\u3000から\u3000昼過ぎ\u3000雨', '西の風', '０．５メートル')
# (48, '410000', '南部', '410010', '2024-12-07T00:00:00+09:00', '200', 'くもり', '北西の風\u3000後\u3000北の風', '０．５メートル')
# (48, '410000', '北部', '410020', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風\u3000唐津地区\u3000では\u3000北西の風\u3000やや強く', '２メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_49
# テーブル weather_forecast_areas_010900_49 のデータ:
# (49, '420000', '南部', '420010', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北の風', '１．５メートル\u3000後\u3000１メートル')
# (49, '420000', '南部', '420010', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000明け方\u3000から\u3000朝\u3000雨', '北の風\u3000後\u3000西の風', '１メートル\u3000後\u3000１．５メートル')
# (49, '420000', '南部', '420010', '2024-12-06T00:00:00+09:00', '200', 'くもり', '北西の風\u3000後\u3000西の風', '１．５メートル')
# (49, '420000', '北部', '420020', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり', '北西の風', '１．５メートル')
# (49, '420000', '北部', '420020', '2024-12-05T00:00:00+09:00', '200', 'くもり', '北西の風\u3000平戸・松浦地区\u3000では\u3000西の風\u3000やや強く', '１．５メートル\u3000後\u3000２メートル')
# (49, '420000', '北部', '420020', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風', '２メートル\u3000後\u3000１．５メートル')
# (49, '420000', '壱岐・対馬', '420030', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル')
# (49, '420000', '壱岐・対馬', '420030', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北西の風\u3000後\u3000西の風\u3000やや強く', '２メートル')
# (49, '420000', '壱岐・対馬', '420030', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '２メートル')
# (49, '420000', '五島', '420040', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり', '北西の風', '１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_50
# テーブル weather_forecast_areas_010900_50 のデータ:
# (50, '430000', '熊本地方', '430010', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000後\u3000東の風', '０．５メートル')
# (50, '430000', '熊本地方', '430010', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北東の風\u3000後\u3000北西の風', '０．５メートル')
# (50, '430000', '熊本地方', '430010', '2024-12-06T00:00:00+09:00', '200', 'くもり', '東の風\u3000後\u3000北西の風', '０．５メートル')
# (50, '430000', '阿蘇地方', '430020', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000後\u3000西の風', 'なし')
# (50, '430000', '阿蘇地方', '430020', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '南西の風\u3000日中\u3000西の風', 'なし')
# (50, '430000', '阿蘇地方', '430020', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風\u3000後\u3000南西の風', 'なし')
# (50, '430000', '天草・芦北地方', '430030', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風', '１メートル\u3000ただし\u3000芦北地方\u3000では\u3000０．５メートル')
# (50, '430000', '天草・芦北地方', '430030', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000朝\u3000から\u3000昼過ぎ\u3000雨', '北の風\u3000後\u3000西の風', '１メートル\u3000ただし\u3000芦北地方\u3000では\u3000０．５メートル')
# (50, '430000', '天草・芦北地方', '430030', '2024-12-06T00:00:00+09:00', '200', 'くもり', '西の風', '１メートル\u3000後\u3000１．５メートル\u3000ただし\u3000芦北地方\u3000では\u3000０．５メートル')
# (50, '430000', '球磨地方', '430040', '2024-12-04T17:00:00+09:00', '100', '晴れ', '西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_51
# テーブル weather_forecast_areas_010900_51 のデータ:
# (51, '440000', '中部', '440010', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000１メートル')
# (51, '440000', '中部', '440010', '2024-12-05T00:00:00+09:00', '211', 'くもり\u3000夕方\u3000から\u3000晴れ', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (51, '440000', '中部', '440010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '南の風\u3000後\u3000北西の風', '１メートル')
# (51, '440000', '北部', '440020', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (51, '440000', '北部', '440020', '2024-12-05T00:00:00+09:00', '211', 'くもり\u3000夕方\u3000から\u3000晴れ', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (51, '440000', '北部', '440020', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル')
# (51, '440000', '西部', '440030', '2024-12-04T17:00:00+09:00', '111', '晴れ\u3000夜遅く\u3000くもり', '北西の風\u3000後\u3000西の風', 'なし')
# (51, '440000', '西部', '440030', '2024-12-05T00:00:00+09:00', '211', 'くもり\u3000夕方\u3000から\u3000晴れ', '西の風', 'なし')
# (51, '440000', '西部', '440030', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', 'なし')
# (51, '440000', '南部', '440040', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル\u3000後\u3000１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011000_52
# テーブル weather_forecast_areas_011000_52 のデータ:
# (52, '450000', '南部平野部', '450010', '2024-12-04T17:00:00+09:00', '100', '晴れ', '西の風\u3000海上\u3000では\u3000北の風\u3000やや強く', '１．５メートル')
# (52, '450000', '南部平野部', '450010', '2024-12-05T00:00:00+09:00', '100', '晴れ\u3000昼前\u3000から\u3000昼過ぎ\u3000くもり', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000１メートル')
# (52, '450000', '南部平野部', '450010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '１メートル')
# (52, '450000', '北部平野部', '450020', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000後\u3000西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル')
# (52, '450000', '北部平野部', '450020', '2024-12-05T00:00:00+09:00', '100', '晴れ\u3000朝\u3000から\u3000昼前\u3000くもり', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000１メートル')
# (52, '450000', '北部平野部', '450020', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '１メートル')
# (52, '450000', '南部山沿い', '450030', '2024-12-04T17:00:00+09:00', '100', '晴れ', '西の風', 'なし')
# (52, '450000', '南部山沿い', '450030', '2024-12-05T00:00:00+09:00', '110', '晴れ\u3000昼前\u3000から\u3000時々\u3000くもり', '西の風', 'なし')
# (52, '450000', '南部山沿い', '450030', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', 'なし')
# (52, '450000', '北部山沿い', '450040', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011000_54
# テーブル weather_forecast_areas_011000_54 のデータ:
# (54, '460100', '薩摩地方', '460010', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000海上\u3000では\u3000北の風\u3000やや強く', '１．５メートル')
# (54, '460100', '薩摩地方', '460010', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000明け方\u3000まで\u3000晴れ\u3000所により\u3000朝\u3000から\u3000昼過ぎ\u3000雨', '北の風\u3000後\u3000北西の風\u3000海上\u3000では\u3000北の風\u3000やや強く', '１．５メートル')
# (54, '460100', '薩摩地方', '460010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', '１．５メートル')
# (54, '460100', '大隅地方', '460020', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル')
# (54, '460100', '大隅地方', '460020', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000朝晩\u3000晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル\u3000後\u3000１メートル')
# (54, '460100', '大隅地方', '460020', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北西の風', '１メートル')
# (54, '460100', '種子島・屋久島地方', '460030', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北西の風\u3000やや強く', '１．５メートル')
# (54, '460100', '種子島・屋久島地方', '460030', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000明け方\u3000まで\u3000晴れ\u3000所により\u3000昼過ぎ\u3000から\u3000夜のはじめ頃\u3000雨', '北西の風\u3000やや強く', '１．５メートル')
# (54, '460100', '種子島・屋久島地方', '460030', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', '１．５メートル')
# (54, '460100', '奄美地方', '460040', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000やや強く', '２メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011100_55
# テーブル weather_forecast_areas_011100_55 のデータ:
# (55, '471000', '本島中南部', '471010', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北東の風\u3000やや強く', '２メートル')
# (55, '471000', '本島中南部', '471010', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000朝晩\u3000晴れ', '北東の風', '２メートル\u3000後\u3000１．５メートル')
# (55, '471000', '本島中南部', '471010', '2024-12-06T00:00:00+09:00', '200', 'くもり', '北東の風', '１．５メートル')
# (55, '471000', '本島北部', '471020', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北東の風\u3000やや強く', '２メートル')
# (55, '471000', '本島北部', '471020', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000朝晩\u3000晴れ', '北東の風', '２メートル\u3000後\u3000１．５メートル')
# (55, '471000', '本島北部', '471020', '2024-12-06T00:00:00+09:00', '200', 'くもり', '北東の風', '１．５メートル')
# (55, '471000', '久米島', '471030', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北東の風\u3000やや強く', '２メートル')
# (55, '471000', '久米島', '471030', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000昼前\u3000まで\u3000時々\u3000晴れ', '北東の風', '２メートル\u3000後\u3000１．５メートル')
# (55, '471000', '久米島', '471030', '2024-12-06T00:00:00+09:00', '200', 'くもり', '北東の風', '１．５メートル')
# (55, '471000', '本島中南部', '471010', '2024-12-05T17:00:00+09:00', '200', 'くもり', '北の風\u3000後\u3000北東の風', '１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011100_56
# テーブル weather_forecast_areas_011100_56 のデータ:
# (56, '472000', '大東島地方', '472000', '2024-12-04T17:00:00+09:00', '100', '晴れ', '北の風\u3000やや強く', '２．５メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-05T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風\u3000後\u3000北東の風', '２メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北東の風', '１．５メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-05T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり', '北の風', '２メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-06T00:00:00+09:00', '210', 'くもり\u3000昼過ぎ\u3000から\u3000時々\u3000晴れ', '北東の風', '１．５メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-07T00:00:00+09:00', '200', 'くもり', '北東の風\u3000後\u3000東の風', '１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011100_57
# テーブル weather_forecast_areas_011100_57 のデータ:
# (57, '473000', '宮古島地方', '473000', '2024-12-04T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雨', '北東の風\u3000やや強く', '２．５メートル')
# (57, '473000', '宮古島地方', '473000', '2024-12-05T00:00:00+09:00', '201', 'くもり\u3000昼前\u3000まで\u3000時々\u3000晴れ\u3000所により\u3000夜\u3000雨', '北東の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル')
# (57, '473000', '宮古島地方', '473000', '2024-12-06T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '東の風\u3000やや強く\u3000後\u3000北東の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# (57, '473000', '宮古島地方', '473000', '2024-12-05T17:00:00+09:00', '203', 'くもり\u3000夜のはじめ頃\u3000雨', '北東の風\u3000やや強く', '２メートル')
# (57, '473000', '宮古島地方', '473000', '2024-12-06T00:00:00+09:00', '212', 'くもり\u3000夜\u3000雨', '東の風\u3000やや強く\u3000後\u3000北東の風\u3000やや強く', '２．５メートル')
# (57, '473000', '宮古島地方', '473000', '2024-12-07T00:00:00+09:00', '203', 'くもり\u3000時々\u3000雨', '北東の風\u3000やや強く', '２．５メートル\u3000後\u3000３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011100_58
# テーブル weather_forecast_areas_011100_58 のデータ:
# (58, '474000', '石垣島地方', '474010', '2024-12-04T17:00:00+09:00', '203', 'くもり\u3000夜のはじめ頃\u3000雨', '北東の風\u3000やや強く', '２．５メートル')
# (58, '474000', '石垣島地方', '474010', '2024-12-05T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '北東の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル')
# (58, '474000', '石垣島地方', '474010', '2024-12-06T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '東の風\u3000やや強く\u3000後\u3000北東の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# (58, '474000', '与那国島地方', '474020', '2024-12-04T17:00:00+09:00', '203', 'くもり\u3000夜のはじめ頃\u3000雨', '北東の風\u3000やや強く', '２．５メートル')
# (58, '474000', '与那国島地方', '474020', '2024-12-05T00:00:00+09:00', '212', 'くもり\u3000夜遅く\u3000雨', '北東の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル')
# (58, '474000', '与那国島地方', '474020', '2024-12-06T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '東の風\u3000やや強く\u3000後\u3000北東の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# (58, '474000', '石垣島地方', '474010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜\u3000雨', '北東の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# (58, '474000', '石垣島地方', '474010', '2024-12-06T00:00:00+09:00', '213', 'くもり\u3000昼過ぎ\u3000から\u3000時々\u3000雨', '東の風\u3000やや強く\u3000後\u3000北東の風\u3000やや強く', '２．５メートル')
# (58, '474000', '石垣島地方', '474010', '2024-12-07T00:00:00+09:00', '203', 'くもり\u3000時々\u3000雨', '北東の風\u3000やや強く', '２．５メートル\u3000後\u3000３メートル')
# (58, '474000', '与那国島地方', '474020', '2024-12-05T17:00:00+09:00', '313', '雨\u3000夜遅く\u3000くもり', '東の風\u3000やや強く\u3000後\u3000北東の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# --------------------------------------------------
# データベースの作成とデータ挿入が完了しました。

# %% [markdown]
# ##  一番見やすい形にしてみる

# %%
import sqlite3
import requests  # 修正：requestsのインポートのスペルを修正

# データベースのパスと名前
db_filename = 'weather_forecast_detail.db'

# 新しいデータベースに接続（存在しない場合は作成されます）
con = sqlite3.connect(db_filename)
cur = con.cursor()

# area_info.dbからデータを取得
area_info_db = 'area_info.db'
con_area_info = sqlite3.connect(area_info_db)
cur_area_info = con_area_info.cursor()

# SQLを実行して、area_infoテーブルからデータを取得 (DISTINCTを使用)
sql_select = "SELECT DISTINCT * FROM area_info;"  # 重複排除
cur_area_info.execute(sql_select)

# 取得したデータをループで処理
for row in cur_area_info:
    # 行データ(row)はタプルなので、アンパックにして列データを取得
    id, area_code, area_name, en_name, office_name, children_code = row
    print(f"id: {id}, area_code: {area_code}, area_name: {area_name}, en_name: {en_name}, office_name: {office_name}, children_code: {children_code}")

    # children_codeを使ってURLを作成
    url = f"https://www.jma.go.jp/bosai/forecast/data/forecast/{children_code}.json"
    
    try:
        # URLからJSONデータを取得
        response = requests.get(url)
        response.raise_for_status()  # 応答が成功しない場合、例外が発生
        
        # JSONデータを解析
        data = response.json()
        
        # 時刻（timeDefines）の情報を取得
        time_defines = data[0]['timeSeries'][0]['timeDefines']
        
        # 各エリアの情報を取得
        area = data[0]['timeSeries'][0]['areas']
        
        # idとarea_code別のテーブル作成
        table_name = f"weather_forecast_areas_{area_code}_{id}"
        
        # 新しいテーブルを作成（area_codeとidをテーブル名にする）
        cur.execute(f"""
        CREATE TABLE IF NOT EXISTS "{table_name}" (
            id INTEGER,
            children_code TEXT,
            area_name TEXT,
            area_code TEXT,
            date TEXT,
            weather_codes TEXT,
            weather TEXT,
            wind TEXT,
            wave TEXT,
            UNIQUE(id, children_code, date)  -- 重複を防ぐためにid, children_code, dateをユニーク制約
        )
        """)
        
        # 各エリアの情報をループ処理
        for area_data in area:
            area_name = area_data['area']['name']
            area_code = area_data['area']['code']
            weather_codes = area_data.get('weatherCodes', ['なし'])
            weathers = area_data.get('weathers', ['なし'])
            winds = area_data.get('winds', ['なし'])
            waves = area_data.get('waves', ['なし'])

            # データを1行ずつDBに挿入
            for i in range(len(time_defines)):
                # 行データを準備
                row_data = (
                    id,  # ID
                    children_code,  # 子供コード
                    area_name,  # 地域名
                    area_code,  # 地域コード
                    time_defines[i],  # 日付
                    weather_codes[i] if i < len(weather_codes) else 'なし',  # 天気コード
                    weathers[i] if i < len(weathers) else 'なし',  # 天気
                    winds[i] if i < len(winds) else 'なし',  # 風
                    waves[i] if i < len(waves) else 'なし'  # 波
                )

                # 重複を避けるために、まずそのデータが存在するか確認
                cur.execute(f"""
                SELECT COUNT(*) FROM "{table_name}" WHERE id = ? AND children_code = ? AND date = ?
                """, (id, children_code, time_defines[i]))
                count = cur.fetchone()[0]

                # 存在しなければデータを挿入
                if count == 0:
                    cur.execute(f"""
                    INSERT INTO "{table_name}" (id, children_code, area_name, area_code, date, weather_codes, weather, wind, wave)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
                    """, row_data)

    except requests.exceptions.RequestException as e:  # リクエストエラーが発生した場合
        print(f"URL {url} からのデータ取得エラー: {e}")

# コミットして変更を保存
con.commit()

# 作成されたテーブルの一覧を表示
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cur.fetchall()
print("作成された一覧テーブル:")
for table in tables:
    table_name = table[0]
    if table_name.startswith("weather_forecast_areas_"):
        print(f"テーブル名: {table_name}")
        
        # 各テーブルのデータを表示（最大10行のみ表示）
        cur.execute(f"SELECT * FROM {table_name} LIMIT 10;")
        rows = cur.fetchall()
        print(f"テーブル {table_name} のデータ:")
        for row in rows:
            print(row)
        print("-" * 50)

# DBへの接続を閉じる
con_area_info.close()
con.close()

print("データベースの作成とデータ挿入が完了しました。")
# Out:
# id: 1, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 011000
# id: 2, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 012000
# id: 3, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 013000
# id: 4, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 014030
# URL https://www.jma.go.jp/bosai/forecast/data/forecast/014030.json からのデータ取得エラー: 404 Client Error: Not Found for url: https://www.jma.go.jp/bosai/forecast/data/forecast/014030.json
# id: 5, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 014100
# id: 6, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 015000
# id: 7, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 016000
# id: 8, area_code: 010100, area_name: 北海道地方, en_name: Hokkaido, office_name: 札幌管区気象台, children_code: 017000
# id: 9, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 020000
# id: 10, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 030000
# id: 11, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 040000
# id: 12, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 050000
# id: 13, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 060000
# id: 14, area_code: 010200, area_name: 東北地方, en_name: Tohoku, office_name: 仙台管区気象台, children_code: 070000
# id: 15, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 080000
# id: 16, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 090000
# id: 17, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 100000
# id: 18, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 110000
# id: 19, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 120000
# id: 20, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 130000
# id: 21, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 140000
# id: 22, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 190000
# id: 23, area_code: 010300, area_name: 関東甲信地方, en_name: Kanto Koshin, office_name: 気象庁, children_code: 200000
# id: 24, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 210000
# id: 25, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 220000
# id: 26, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 230000
# id: 27, area_code: 010400, area_name: 東海地方, en_name: Tokai, office_name: 名古屋地方気象台, children_code: 240000
# id: 28, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 150000
# id: 29, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 160000
# id: 30, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 170000
# id: 31, area_code: 010500, area_name: 北陸地方, en_name: Hokuriku, office_name: 新潟地方気象台, children_code: 180000
# id: 32, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 250000
# id: 33, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 260000
# id: 34, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 270000
# id: 35, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 280000
# id: 36, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 290000
# id: 37, area_code: 010600, area_name: 近畿地方, en_name: Kinki, office_name: 大阪管区気象台, children_code: 300000
# id: 38, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 310000
# id: 39, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 320000
# id: 40, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 330000
# id: 41, area_code: 010700, area_name: 中国地方（山口県を除く）, en_name: Chugoku (Excluding Yamaguchi), office_name: 広島地方気象台, children_code: 340000
# id: 42, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 360000
# id: 43, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 370000
# id: 44, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 380000
# id: 45, area_code: 010800, area_name: 四国地方, en_name: Shikoku, office_name: 高松地方気象台, children_code: 390000
# id: 46, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 350000
# id: 47, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 400000
# id: 48, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 410000
# id: 49, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 420000
# id: 50, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 430000
# id: 51, area_code: 010900, area_name: 九州北部地方（山口県を含む）, en_name: Northern Kyushu (Including Yamaguchi), office_name: 福岡管区気象台, children_code: 440000
# id: 52, area_code: 011000, area_name: 九州南部・奄美地方, en_name: Southern Kyushu and Amami, office_name: 鹿児島地方気象台, children_code: 450000
# id: 53, area_code: 011000, area_name: 九州南部・奄美地方, en_name: Southern Kyushu and Amami, office_name: 鹿児島地方気象台, children_code: 460040
# URL https://www.jma.go.jp/bosai/forecast/data/forecast/460040.json からのデータ取得エラー: 404 Client Error: Not Found for url: https://www.jma.go.jp/bosai/forecast/data/forecast/460040.json
# id: 54, area_code: 011000, area_name: 九州南部・奄美地方, en_name: Southern Kyushu and Amami, office_name: 鹿児島地方気象台, children_code: 460100
# id: 55, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 471000
# id: 56, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 472000
# id: 57, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 473000
# id: 58, area_code: 011100, area_name: 沖縄地方, en_name: Okinawa, office_name: 沖縄気象台, children_code: 474000
# 作成された一覧テーブル:
# テーブル名: weather_forecast_areas_010100_1
# テーブル weather_forecast_areas_010100_1 のデータ:
# (1, '011000', '宗谷地方', '011000', '2024-12-05T17:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000夜のはじめ頃\u3000くもり', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-06T00:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000時々\u3000くもり\u3000所により\u3000朝\u3000から\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-07T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪\u3000で\u3000ふぶく', '北西の風\u3000やや強く\u3000後\u3000西の風\u3000やや強く', '３メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-06T11:00:00+09:00', '217', 'くもり\u3000昼過ぎ\u3000から\u3000雪\u3000で\u3000ふぶく\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000３メートル')
# (1, '011000', '宗谷地方', '011000', '2024-12-08T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪', '北西の風\u3000後\u3000北の風', '２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_2
# テーブル weather_forecast_areas_010100_2 のデータ:
# (2, '012000', '上川地方', '012010', '2024-12-05T17:00:00+09:00', '413', '雪\u3000夜遅く\u3000くもり', '西の風\u3000後\u3000南の風', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-06T00:00:00+09:00', '402', '雪\u3000昼前\u3000まで\u3000時々\u3000くもり\u3000所により\u3000朝\u3000から\u3000雷\u3000を伴う', '南東の風\u3000後\u3000西の風', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-07T00:00:00+09:00', '402', '雪\u3000時々\u3000くもり', '西の風', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-06T11:00:00+09:00', '217', 'くもり\u3000昼過ぎ\u3000から\u3000雪\u3000で\u3000ふぶく\u3000所により\u3000雷\u3000を伴う', '南の風\u3000後\u3000西の風\u3000やや強く', 'なし')
# (2, '012000', '上川地方', '012010', '2024-12-08T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪', '南の風\u3000後\u3000北の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_3
# テーブル weather_forecast_areas_010100_3 のデータ:
# (3, '013000', '網走地方', '013010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり\u3000所により\u3000夕方\u3000雪', '南の風\u3000後\u3000西の風\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル\u3000後\u3000２．５メートル')
# (3, '013000', '網走地方', '013010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000夜遅く\u3000雪', '南の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '２．５メートル')
# (3, '013000', '網走地方', '013010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '３メートル')
# (3, '013000', '網走地方', '013010', '2024-12-06T11:00:00+09:00', '200', 'くもり\u3000昼過ぎ\u3000晴れ\u3000所により\u3000夕方\u3000から\u3000雪', '南の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '１．５メートル\u3000後\u3000２．５メートル')
# (3, '013000', '網走地方', '013010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000後\u3000北西の風', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_5
# テーブル weather_forecast_areas_010100_5 のデータ:
# (5, '014100', '釧路地方', '014020', '2024-12-05T17:00:00+09:00', '100', '晴れ', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000２メートル')
# (5, '014100', '釧路地方', '014020', '2024-12-06T00:00:00+09:00', '110', '晴れ\u3000昼前\u3000から\u3000時々\u3000くもり\u3000所により\u3000雪', '西の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '２メートル\u3000後\u3000２．５メートル')
# (5, '014100', '釧路地方', '014020', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000やや強く', '３メートル')
# (5, '014100', '釧路地方', '014020', '2024-12-06T11:00:00+09:00', '211', 'くもり\u3000夕方\u3000から\u3000晴れ\u3000所により\u3000昼過ぎ\u3000まで\u3000雪', '北西の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '１メートル\u3000後\u3000２．５メートル')
# (5, '014100', '釧路地方', '014020', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_6
# テーブル weather_forecast_areas_010100_6 のデータ:
# (6, '015000', '胆振地方', '015010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雪', '西の風\u3000やや強く', '２メートル\u3000後\u3000１メートル')
# (6, '015000', '胆振地方', '015010', '2024-12-06T00:00:00+09:00', '216', 'くもり\u3000昼前\u3000から\u3000時々\u3000雪\u3000で\u3000ふぶく\u3000所により\u3000夕方\u3000から\u3000雷\u3000を伴う', '北の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '１メートル\u3000後\u3000２．５メートル')
# (6, '015000', '胆振地方', '015010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000やや強く\u3000後\u3000西の風\u3000やや強く', '２メートル')
# (6, '015000', '胆振地方', '015010', '2024-12-06T11:00:00+09:00', '217', 'くもり\u3000夜\u3000雪\u3000で\u3000ふぶく\u3000所により\u3000夕方\u3000から\u3000雷\u3000を伴う', '西の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '１メートル\u3000後\u3000３メートル')
# (6, '015000', '胆振地方', '015010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_7
# テーブル weather_forecast_areas_010100_7 のデータ:
# (7, '016000', '石狩地方', '016010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪\u3000で\u3000ふぶく', '北西の風\u3000後\u3000西の風\u3000石狩北部\u3000では\u3000西の風\u3000やや強く', '３メートル')
# (7, '016000', '石狩地方', '016010', '2024-12-06T00:00:00+09:00', '217', 'くもり\u3000昼過ぎ\u3000から\u3000雪\u3000所により\u3000朝\u3000から\u3000雷\u3000を伴う', '南の風\u3000後\u3000西の風\u3000石狩北部\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000４メートル')
# (7, '016000', '石狩地方', '016010', '2024-12-07T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪\u3000で\u3000ふぶく', '北西の風\u3000やや強く', '４メートル\u3000後\u3000３メートル')
# (7, '016000', '石狩地方', '016010', '2024-12-06T11:00:00+09:00', '217', 'くもり\u3000昼過ぎ\u3000から\u3000雪\u3000で\u3000ふぶく\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000やや強く\u3000石狩北部\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000４メートル')
# (7, '016000', '石狩地方', '016010', '2024-12-08T00:00:00+09:00', '204', 'くもり\u3000一時\u3000雪', '北西の風', '２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010100_8
# テーブル weather_forecast_areas_010100_8 のデータ:
# (8, '017000', '渡島地方', '017010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雪', '西の風\u3000やや強く\u3000後\u3000北西の風\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000強く', '３メートル')
# (8, '017000', '渡島地方', '017010', '2024-12-06T00:00:00+09:00', '402', '雪\u3000で\u3000ふぶく\u3000昼過ぎ\u3000まで\u3000時々\u3000くもり\u3000所により\u3000朝\u3000から\u3000雷\u3000を伴う', '北西の風\u3000後\u3000西の風\u3000やや強く\u3000渡島西部\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000５メートル')
# (8, '017000', '渡島地方', '017010', '2024-12-07T00:00:00+09:00', '204', 'くもり\u3000一時\u3000雪\u3000で\u3000ふぶく', '北西の風\u3000やや強く\u3000後\u3000西の風', '５メートル\u3000後\u3000３メートル')
# (8, '017000', '渡島地方', '017010', '2024-12-06T11:00:00+09:00', '400', '雪\u3000で\u3000ふぶく\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000やや強く\u3000渡島西部\u3000では\u3000後\u3000西の風\u3000非常に強く', '２．５メートル\u3000後\u3000５メートル')
# (8, '017000', '渡島地方', '017010', '2024-12-08T00:00:00+09:00', '204', 'くもり\u3000一時\u3000雪', '西の風', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_9
# テーブル weather_forecast_areas_010200_9 のデータ:
# (9, '020000', '津軽', '020010', '2024-12-05T17:00:00+09:00', '281', 'くもり\u3000夜遅く\u3000雪か雨', '西の風\u3000後\u3000南の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２．５メートル')
# (9, '020000', '津軽', '020010', '2024-12-06T00:00:00+09:00', '406', '雪か雨\u3000所により\u3000明け方\u3000から\u3000雷\u3000を伴う', '南の風\u3000後\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000５メートル')
# (9, '020000', '津軽', '020010', '2024-12-07T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪\u3000で\u3000ふぶく', '西の風\u3000やや強く', '４メートル\u3000後\u3000３メートル')
# (9, '020000', '津軽', '020010', '2024-12-06T11:00:00+09:00', '406', '雪\u3000で\u3000ふぶく\u3000所により\u3000雷\u3000を伴う', '西の風\u3000強く\u3000後\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000非常に強く', '４メートル\u3000後\u3000５メートル')
# (9, '020000', '津軽', '020010', '2024-12-08T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪\u3000で\u3000ふぶく', '西の風\u3000やや強く', '４メートル\u3000後\u3000３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_10
# テーブル weather_forecast_areas_010200_10 のデータ:
# (10, '030000', '内陸', '030010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雪か雨', '東の風', 'なし')
# (10, '030000', '内陸', '030010', '2024-12-06T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '南の風\u3000後\u3000西の風\u3000やや強く', 'なし')
# (10, '030000', '内陸', '030010', '2024-12-07T00:00:00+09:00', '204', 'くもり\u3000一時\u3000雪', '西の風', 'なし')
# (10, '030000', '内陸', '030010', '2024-12-06T11:00:00+09:00', '402', '雪か雨\u3000夕方\u3000から\u3000夜のはじめ頃\u3000くもり\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', '西の風\u3000やや強く', 'なし')
# (10, '030000', '内陸', '030010', '2024-12-08T00:00:00+09:00', '204', 'くもり\u3000一時\u3000雪', '西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_11
# テーブル weather_forecast_areas_010200_11 のデータ:
# (11, '040000', '東部', '040010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雨か雪', '西の風\u3000後\u3000北の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (11, '040000', '東部', '040010', '2024-12-06T00:00:00+09:00', '102', '晴れ\u3000時々\u3000くもり\u3000昼前\u3000一時\u3000雨', '南西の風\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000南西の風\u3000強く', '１メートル\u3000後\u3000２メートル')
# (11, '040000', '東部', '040010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000やや強く', '１．５メートル')
# (11, '040000', '東部', '040010', '2024-12-06T11:00:00+09:00', '211', 'くもり\u3000夕方\u3000から\u3000晴れ\u3000所により\u3000雨か雪\u3000で\u3000雷を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル')
# (11, '040000', '東部', '040010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く', '２メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_12
# テーブル weather_forecast_areas_010200_12 のデータ:
# (12, '050000', '沿岸', '050010', '2024-12-05T17:00:00+09:00', '340', '雪か雨\u3000所により\u3000雷\u3000を伴う', '北西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '３メートル')
# (12, '050000', '沿岸', '050010', '2024-12-06T00:00:00+09:00', '406', '雪か雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000強く\u3000海上\u3000では\u3000西の風\u3000非常に強く', '３メートル\u3000後\u3000５メートル')
# (12, '050000', '沿岸', '050010', '2024-12-07T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪\u3000で\u3000ふぶく', '西の風\u3000やや強く', '４メートル\u3000後\u3000３メートル')
# (12, '050000', '沿岸', '050010', '2024-12-06T11:00:00+09:00', '406', '雪か雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000強く\u3000海上\u3000では\u3000北西の風\u3000非常に強く', '５メートル')
# (12, '050000', '沿岸', '050010', '2024-12-08T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪\u3000で\u3000ふぶく', '西の風\u3000やや強く', '４メートル\u3000後\u3000３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_13
# テーブル weather_forecast_areas_010200_13 のデータ:
# (13, '060000', '村山', '060010', '2024-12-05T17:00:00+09:00', '304', '雨か雪\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000南の風', 'なし')
# (13, '060000', '村山', '060010', '2024-12-06T00:00:00+09:00', '304', '雨か雪\u3000所により\u3000雷\u3000を伴う', '西の風', 'なし')
# (13, '060000', '村山', '060010', '2024-12-07T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪', '西の風', 'なし')
# (13, '060000', '村山', '060010', '2024-12-06T11:00:00+09:00', '304', '雨か雪\u3000所により\u3000雷\u3000を伴う', '西の風', 'なし')
# (13, '060000', '村山', '060010', '2024-12-08T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪', '西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010200_14
# テーブル weather_forecast_areas_010200_14 のデータ:
# (14, '070000', '中通り', '070010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨か雪', '西の風\u3000後\u3000南西の風', 'なし')
# (14, '070000', '中通り', '070010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000雨か雪', '西の風\u3000後\u3000北西の風', 'なし')
# (14, '070000', '中通り', '070010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', 'なし')
# (14, '070000', '中通り', '070010', '2024-12-06T11:00:00+09:00', '200', 'くもり\u3000夕方\u3000晴れ\u3000所により\u3000雨か雪', '西の風\u3000後\u3000北西の風', 'なし')
# (14, '070000', '中通り', '070010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_15
# テーブル weather_forecast_areas_010300_15 のデータ:
# (15, '080000', '北部', '080010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２メートル')
# (15, '080000', '北部', '080010', '2024-12-06T00:00:00+09:00', '110', '晴れ\u3000昼過ぎ\u3000から\u3000時々\u3000くもり', '西の風\u3000後\u3000南西の風\u3000やや強く\u3000海上\u3000では\u3000南西の風\u3000強く', '２メートル\u3000後\u3000２．５メートル')
# (15, '080000', '北部', '080010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風', '２メートル\u3000後\u3000１．５メートル')
# (15, '080000', '北部', '080010', '2024-12-06T11:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '南西の風\u3000やや強く\u3000後\u3000西の風\u3000やや強く\u3000海上\u3000では\u3000南西の風\u3000強く', '２．５メートル')
# (15, '080000', '北部', '080010', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風', '１．５メートル\u3000後\u3000２メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_16
# テーブル weather_forecast_areas_010300_16 のデータ:
# (16, '090000', '南部', '090010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北の風', 'なし')
# (16, '090000', '南部', '090010', '2024-12-06T00:00:00+09:00', '110', '晴れ\u3000昼過ぎ\u3000から\u3000時々\u3000くもり', '南西の風\u3000日中\u3000やや強く', 'なし')
# (16, '090000', '南部', '090010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風\u3000後\u3000北東の風', 'なし')
# (16, '090000', '南部', '090010', '2024-12-06T11:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '南西の風\u3000やや強く', 'なし')
# (16, '090000', '南部', '090010', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_17
# テーブル weather_forecast_areas_010300_17 のデータ:
# (17, '100000', '南部', '100010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北西の風', 'なし')
# (17, '100000', '南部', '100010', '2024-12-06T00:00:00+09:00', '110', '晴れ\u3000昼過ぎ\u3000から\u3000時々\u3000くもり', '北西の風', 'なし')
# (17, '100000', '南部', '100010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風', 'なし')
# (17, '100000', '南部', '100010', '2024-12-06T11:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北西の風', 'なし')
# (17, '100000', '南部', '100010', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_18
# テーブル weather_forecast_areas_010300_18 のデータ:
# (18, '110000', '北部', '110020', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '南東の風\u3000後\u3000北西の風', 'なし')
# (18, '110000', '北部', '110020', '2024-12-06T00:00:00+09:00', '100', '晴れ', '南西の風\u3000後\u3000北西の風', 'なし')
# (18, '110000', '北部', '110020', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北東の風\u3000後\u3000北西の風', 'なし')
# (18, '110000', '北部', '110020', '2024-12-06T11:00:00+09:00', '100', '晴れ', '北西の風', 'なし')
# (18, '110000', '北部', '110020', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北西の風\u3000後\u3000西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_19
# テーブル weather_forecast_areas_010300_19 のデータ:
# (19, '120000', '北西部', '120010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北の風', '０．５メートル')
# (19, '120000', '北西部', '120010', '2024-12-06T00:00:00+09:00', '100', '晴れ', '西の風\u3000日中\u3000南西の風\u3000やや強く', '０．５メートル\u3000後\u3000１．５メートル')
# (19, '120000', '北西部', '120010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000後\u3000北の風', '０．５メートル')
# (19, '120000', '北西部', '120010', '2024-12-06T11:00:00+09:00', '100', '晴れ', '南西の風\u3000やや強く\u3000後\u3000西の風', '１．５メートル\u3000後\u3000０．５メートル')
# (19, '120000', '北西部', '120010', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北西の風', '０．５メートル\u3000後\u3000１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_20
# テーブル weather_forecast_areas_010300_20 のデータ:
# (20, '130000', '東京地方', '130010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '南の風\u3000後\u3000北の風', '０．５メートル')
# (20, '130000', '東京地方', '130010', '2024-12-06T00:00:00+09:00', '100', '晴れ', '北西の風\u3000後\u3000南西の風\u3000２３区西部\u3000では\u3000南西の風\u3000やや強く', '０．５メートル\u3000後\u3000１．５メートル')
# (20, '130000', '東京地方', '130010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北東の風', '０．５メートル')
# (20, '130000', '東京地方', '130010', '2024-12-06T11:00:00+09:00', '100', '晴れ', '南西の風\u3000２３区西部\u3000では\u3000南西の風\u3000やや強く', '１．５メートル\u3000後\u3000０．５メートル')
# (20, '130000', '東京地方', '130010', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風\u3000後\u3000北西の風\u3000やや強く', '０．５メートル\u3000後\u3000１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_21
# テーブル weather_forecast_areas_010300_21 のデータ:
# (21, '140000', '東部', '140010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル\u3000後\u3000１．５メートル')
# (21, '140000', '東部', '140010', '2024-12-06T00:00:00+09:00', '100', '晴れ', '西の風\u3000日中\u3000南西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '１．５メートル\u3000後\u3000２メートル')
# (21, '140000', '東部', '140010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000後\u3000北の風', '１．５メートル\u3000後\u3000１メートル')
# (21, '140000', '東部', '140010', '2024-12-06T11:00:00+09:00', '100', '晴れ', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル')
# (21, '140000', '東部', '140010', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北の風', '１．５メートル\u3000後\u3000１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_22
# テーブル weather_forecast_areas_010300_22 のデータ:
# (22, '190000', '中・西部', '190010', '2024-12-05T17:00:00+09:00', '100', '晴れ', '北西の風', 'なし')
# (22, '190000', '中・西部', '190010', '2024-12-06T00:00:00+09:00', '100', '晴れ', '北西の風', 'なし')
# (22, '190000', '中・西部', '190010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '南の風\u3000後\u3000北西の風', 'なし')
# (22, '190000', '中・西部', '190010', '2024-12-06T11:00:00+09:00', '100', '晴れ', '北西の風', 'なし')
# (22, '190000', '中・西部', '190010', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '南の風\u3000後\u3000西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010300_23
# テーブル weather_forecast_areas_010300_23 のデータ:
# (23, '200000', '北部', '200010', '2024-12-05T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり\u3000所により\u3000雪か雨', '南の風', 'なし')
# (23, '200000', '北部', '200010', '2024-12-06T00:00:00+09:00', '207', 'くもり\u3000昼前\u3000から\u3000夕方\u3000雨か雪\u3000所により\u3000昼前\u3000から\u3000雷\u3000を伴う', '南の風\u3000後\u3000北の風', 'なし')
# (23, '200000', '北部', '200010', '2024-12-07T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪', '北東の風\u3000後\u3000北の風', 'なし')
# (23, '200000', '北部', '200010', '2024-12-06T11:00:00+09:00', '317', '雨か雪\u3000夜\u3000くもり\u3000所により\u3000雷\u3000を伴う', '南の風', 'なし')
# (23, '200000', '北部', '200010', '2024-12-08T00:00:00+09:00', '205', 'くもり\u3000時々\u3000雪', '東の風\u3000後\u3000北の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010400_24
# テーブル weather_forecast_areas_010400_24 のデータ:
# (24, '210000', '美濃地方', '210010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨か雪\u3000で\u3000雷を伴う', '西の風\u3000後\u3000東の風', 'なし')
# (24, '210000', '美濃地方', '210010', '2024-12-06T00:00:00+09:00', '218', 'くもり\u3000昼過ぎ\u3000から\u3000夕方\u3000雨か雪\u3000所により\u3000雷\u3000を伴う', '東の風\u3000後\u3000西の風', 'なし')
# (24, '210000', '美濃地方', '210010', '2024-12-07T00:00:00+09:00', '200', 'くもり', '西の風', 'なし')
# (24, '210000', '美濃地方', '210010', '2024-12-06T11:00:00+09:00', '206', 'くもり\u3000夕方\u3000一時\u3000雨か雪\u3000所により\u3000雷\u3000を伴う', '西の風', 'なし')
# (24, '210000', '美濃地方', '210010', '2024-12-08T00:00:00+09:00', '210', 'くもり\u3000後\u3000時々\u3000晴れ', '北西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010400_25
# テーブル weather_forecast_areas_010400_25 のデータ:
# (25, '220000', '中部', '220010', '2024-12-05T17:00:00+09:00', '100', '晴れ', '西の風\u3000やや強く\u3000海上\u3000では\u3000後\u3000西の風\u3000強く', '２メートル')
# (25, '220000', '中部', '220010', '2024-12-06T00:00:00+09:00', '100', '晴れ', '西の風\u3000後\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル')
# (25, '220000', '中部', '220010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000やや強く', '２メートル')
# (25, '220000', '中部', '220010', '2024-12-06T11:00:00+09:00', '100', '晴れ', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '２メートル')
# (25, '220000', '中部', '220010', '2024-12-08T00:00:00+09:00', '100', '晴れ', '西の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010400_26
# テーブル weather_forecast_areas_010400_26 のデータ:
# (26, '230000', '西部', '230010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '０．５メートル')
# (26, '230000', '西部', '230010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '０．５メートル')
# (26, '230000', '西部', '230010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '０．５メートル')
# (26, '230000', '西部', '230010', '2024-12-06T11:00:00+09:00', '101', '晴れ\u3000昼過ぎ\u3000から\u3000夕方\u3000くもり', '西の風\u3000後\u3000北西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '０．５メートル')
# (26, '230000', '西部', '230010', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000後\u3000北西の風', '０．５メートル\u3000後\u3000１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010400_27
# テーブル weather_forecast_areas_010400_27 のデータ:
# (27, '240000', '北中部', '240010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '０．５メートル')
# (27, '240000', '北中部', '240010', '2024-12-06T00:00:00+09:00', '110', '晴れ\u3000昼前\u3000から\u3000時々\u3000くもり', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '０．５メートル')
# (27, '240000', '北中部', '240010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '０．５メートル')
# (27, '240000', '北中部', '240010', '2024-12-06T11:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '０．５メートル')
# (27, '240000', '北中部', '240010', '2024-12-08T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000後\u3000北西の風', '０．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010500_28
# テーブル weather_forecast_areas_010500_28 のデータ:
# (28, '150000', '下越', '150010', '2024-12-05T17:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル')
# (28, '150000', '下越', '150010', '2024-12-06T00:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000後\u3000強く', '５メートル\u3000後\u3000４メートル')
# (28, '150000', '下越', '150010', '2024-12-07T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '北西の風\u3000やや強く\u3000後\u3000西の風\u3000やや強く', '４メートル\u3000後\u3000３メートル\u3000うねり\u3000を伴う')
# (28, '150000', '下越', '150010', '2024-12-06T11:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '北西の風\u3000強く\u3000後\u3000やや強く\u3000海上\u3000では\u3000はじめ\u3000西の風\u3000非常に強く', '６メートル\u3000後\u3000４メートル')
# (28, '150000', '下越', '150010', '2024-12-08T00:00:00+09:00', '270', 'くもり\u3000時々\u3000雪か雨', '南西の風\u3000後\u3000北西の風\u3000やや強く', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010500_29
# テーブル weather_forecast_areas_010500_29 のデータ:
# (29, '160000', '東部', '160010', '2024-12-05T17:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '南西の風\u3000東部北\u3000では\u3000南西の風\u3000強く', '１．５メートル')
# (29, '160000', '東部', '160010', '2024-12-06T00:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '南西の風\u3000やや強く\u3000東部北\u3000では\u3000南西の風\u3000強く', '１．５メートル\u3000後\u3000２．５メートル')
# (29, '160000', '東部', '160010', '2024-12-07T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '南の風\u3000後\u3000北の風', '２．５メートル\u3000後\u3000１．５メートル\u3000うねり\u3000を伴う')
# (29, '160000', '東部', '160010', '2024-12-06T11:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000後\u3000南西の風\u3000東部北\u3000では\u3000西の風\u3000強く', '２．５メートル\u3000後\u3000２メートル')
# (29, '160000', '東部', '160010', '2024-12-08T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '南の風\u3000後\u3000北の風', '１．５メートル\u3000後\u3000２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010500_30
# テーブル weather_forecast_areas_010500_30 のデータ:
# (30, '170000', '加賀', '170010', '2024-12-05T17:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く', '３メートル')
# (30, '170000', '加賀', '170010', '2024-12-06T00:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '４メートル\u3000後\u3000５メートル')
# (30, '170000', '加賀', '170010', '2024-12-07T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '西の風\u3000やや強く\u3000後\u3000北東の風', '４メートル\u3000後\u3000２．５メートル\u3000うねり\u3000を伴う')
# (30, '170000', '加賀', '170010', '2024-12-06T11:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '５メートル\u3000後\u3000４メートル')
# (30, '170000', '加賀', '170010', '2024-12-08T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '南の風\u3000後\u3000北東の風\u3000やや強く', '２．５メートル\u3000後\u3000３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010500_31
# テーブル weather_forecast_areas_010500_31 のデータ:
# (31, '180000', '嶺北', '180010', '2024-12-05T17:00:00+09:00', '203', 'くもり\u3000時々\u3000雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000後\u3000南の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '３メートル')
# (31, '180000', '嶺北', '180010', '2024-12-06T00:00:00+09:00', '302', '雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', '南の風\u3000後\u3000西の風\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル\u3000後\u3000４メートル')
# (31, '180000', '嶺北', '180010', '2024-12-07T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '西の風', '３メートル')
# (31, '180000', '嶺北', '180010', '2024-12-06T11:00:00+09:00', '203', 'くもり\u3000時々\u3000雨\u3000所により\u3000雷\u3000を伴う', '西の風\u3000海上\u3000では\u3000西の風\u3000強く', '４メートル')
# (31, '180000', '嶺北', '180010', '2024-12-08T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '南の風\u3000後\u3000北の風\u3000やや強く', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010600_32
# テーブル weather_forecast_areas_010600_32 のデータ:
# (32, '250000', '南部', '250010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北西の風\u3000琵琶湖\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', 'なし')
# (32, '250000', '南部', '250010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000後\u3000北西の風\u3000琵琶湖\u3000では\u3000後\u3000北西の風\u3000やや強く', 'なし')
# (32, '250000', '南部', '250010', '2024-12-07T00:00:00+09:00', '200', 'くもり', '西の風', 'なし')
# (32, '250000', '南部', '250010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000昼過ぎ\u3000から\u3000夕方\u3000雨', '西の風\u3000後\u3000北西の風\u3000琵琶湖\u3000では\u3000北西の風\u3000やや強く', 'なし')
# (32, '250000', '南部', '250010', '2024-12-08T00:00:00+09:00', '200', 'くもり', '北西の風\u3000後\u3000やや強く', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010600_33
# テーブル weather_forecast_areas_010600_33 のデータ:
# (33, '260000', '南部', '260010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ', '西の風', 'なし')
# (33, '260000', '南部', '260010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', 'なし')
# (33, '260000', '南部', '260010', '2024-12-07T00:00:00+09:00', '200', 'くもり', '西の風', 'なし')
# (33, '260000', '南部', '260010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000夕方\u3000まで\u3000雨', '西の風', 'なし')
# (33, '260000', '南部', '260010', '2024-12-08T00:00:00+09:00', '200', 'くもり', '西の風\u3000後\u3000北西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010600_34
# テーブル weather_forecast_areas_010600_34 のデータ:
# (34, '270000', '大阪府', '270000', '2024-12-05T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (34, '270000', '大阪府', '270000', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000日中\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '１メートル\u3000後\u3000１．５メートル')
# (34, '270000', '大阪府', '270000', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル')
# (34, '270000', '大阪府', '270000', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '１．５メートル\u3000後\u3000１メートル')
# (34, '270000', '大阪府', '270000', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000後\u3000やや強く', '１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010600_35
# テーブル weather_forecast_areas_010600_35 のデータ:
# (35, '280000', '南部', '280010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ', '西の風\u3000やや強く', '１メートル')
# (35, '280000', '南部', '280010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '１メートル\u3000後\u3000１．５メートル')
# (35, '280000', '南部', '280010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く', '１メートル')
# (35, '280000', '南部', '280010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '１．５メートル\u3000後\u3000１メートル')
# (35, '280000', '南部', '280010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く', '１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010600_36
# テーブル weather_forecast_areas_010600_36 のデータ:
# (36, '290000', '北部', '290010', '2024-12-05T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '西の風', 'なし')
# (36, '290000', '北部', '290010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', 'なし')
# (36, '290000', '北部', '290010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', 'なし')
# (36, '290000', '北部', '290010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', 'なし')
# (36, '290000', '北部', '290010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000後\u3000北西の風', 'なし')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010600_37
# テーブル weather_forecast_areas_010600_37 のデータ:
# (37, '300000', '北部', '300010', '2024-12-05T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル')
# (37, '300000', '北部', '300010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル')
# (37, '300000', '北部', '300010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', '１．５メートル')
# (37, '300000', '北部', '300010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル')
# (37, '300000', '北部', '300010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000後\u3000やや強く', '１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010700_38
# テーブル weather_forecast_areas_010700_38 のデータ:
# (38, '310000', '東部', '310010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨か雪\u3000で\u3000雷を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル')
# (38, '310000', '東部', '310010', '2024-12-06T00:00:00+09:00', '200', 'くもり\u3000所により\u3000朝\u3000から\u3000雨\u3000で\u3000雷を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル\u3000後\u3000４メートル')
# (38, '310000', '東部', '310010', '2024-12-07T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '西の風\u3000やや強く', '３メートル')
# (38, '310000', '東部', '310010', '2024-12-06T11:00:00+09:00', '200', 'くもり\u3000所により\u3000雨か雪\u3000で\u3000雷を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '４メートル\u3000後\u3000３メートル')
# (38, '310000', '東部', '310010', '2024-12-08T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '西の風\u3000やや強く\u3000後\u3000北の風\u3000やや強く', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010700_39
# テーブル weather_forecast_areas_010700_39 のデータ:
# (39, '320000', '東部', '320010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨\u3000で\u3000雷を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル')
# (39, '320000', '東部', '320010', '2024-12-06T00:00:00+09:00', '200', 'くもり\u3000所により\u3000朝\u3000から\u3000昼過ぎ\u3000雨\u3000で\u3000雷を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル')
# (39, '320000', '東部', '320010', '2024-12-07T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '西の風\u3000やや強く', '３メートル')
# (39, '320000', '東部', '320010', '2024-12-06T11:00:00+09:00', '200', 'くもり\u3000所により\u3000雨\u3000で\u3000雷を伴う', '西の風\u3000やや強く\u3000海上\u3000では\u3000西の風\u3000強く', '３メートル')
# (39, '320000', '東部', '320010', '2024-12-08T00:00:00+09:00', '207', 'くもり\u3000時々\u3000雨か雪', '西の風\u3000やや強く\u3000後\u3000北西の風\u3000やや強く', '３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010700_40
# テーブル weather_forecast_areas_010700_40 のデータ:
# (40, '330000', '南部', '330010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (40, '330000', '南部', '330010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000日中\u3000やや強く', '１メートル')
# (40, '330000', '南部', '330010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル')
# (40, '330000', '南部', '330010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く', '１メートル\u3000後\u3000０．５メートル')
# (40, '330000', '南部', '330010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000後\u3000北西の風', '０．５メートル\u3000後\u3000１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010700_41
# テーブル weather_forecast_areas_010700_41 のデータ:
# (41, '340000', '南部', '340010', '2024-12-05T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ\u3000所により\u3000雨\u3000で\u3000雷を伴う', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (41, '340000', '南部', '340010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000夕方\u3000まで\u3000雨\u3000で\u3000雷を伴う', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (41, '340000', '南部', '340010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風', '１メートル')
# (41, '340000', '南部', '340010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く', '１メートル\u3000後\u3000０．５メートル')
# (41, '340000', '南部', '340010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', '０．５メートル\u3000後\u3000１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010800_42
# テーブル weather_forecast_areas_010800_42 のデータ:
# (42, '360000', '北部', '360010', '2024-12-05T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '北西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (42, '360000', '北部', '360010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (42, '360000', '北部', '360010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風\u3000後\u3000西の風', '１メートル')
# (42, '360000', '北部', '360010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (42, '360000', '北部', '360010', '2024-12-08T00:00:00+09:00', '206', 'くもり\u3000一時\u3000雨か雪', '西の風\u3000やや強く', '１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010800_43
# テーブル weather_forecast_areas_010800_43 のデータ:
# (43, '370000', '香川県', '370000', '2024-12-05T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (43, '370000', '香川県', '370000', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000日中\u3000やや強く', '１メートル')
# (43, '370000', '香川県', '370000', '2024-12-07T00:00:00+09:00', '200', 'くもり', '西の風\u3000後\u3000やや強く', '１メートル')
# (43, '370000', '香川県', '370000', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く', '１メートル')
# (43, '370000', '香川県', '370000', '2024-12-08T00:00:00+09:00', '206', 'くもり\u3000一時\u3000雨か雪', '西の風\u3000やや強く', '１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010800_44
# テーブル weather_forecast_areas_010800_44 のデータ:
# (44, '380000', '中予', '380010', '2024-12-05T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ', '西の風\u3000やや強く', '１メートル')
# (44, '380000', '中予', '380010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く', '１メートル')
# (44, '380000', '中予', '380010', '2024-12-07T00:00:00+09:00', '200', 'くもり', '西の風', '１メートル')
# (44, '380000', '中予', '380010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '西の風\u3000やや強く', '１メートル')
# (44, '380000', '中予', '380010', '2024-12-08T00:00:00+09:00', '206', 'くもり\u3000一時\u3000雨か雪', '北西の風\u3000やや強く', '１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010800_45
# テーブル weather_forecast_areas_010800_45 のデータ:
# (45, '390000', '中部', '390010', '2024-12-05T17:00:00+09:00', '101', '晴れ\u3000夜のはじめ頃\u3000くもり', '北西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル')
# (45, '390000', '中部', '390010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000後\u3000北西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１．５メートル')
# (45, '390000', '中部', '390010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風', '１．５メートル')
# (45, '390000', '中部', '390010', '2024-12-06T11:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '西の風\u3000後\u3000北西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１．５メートル')
# (45, '390000', '中部', '390010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北の風\u3000やや強く\u3000後\u3000北西の風\u3000やや強く', '１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_46
# テーブル weather_forecast_areas_010900_46 のデータ:
# (46, '350000', '西部', '350010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨\u3000で\u3000雷を伴う', '西の風\u3000やや強く', '２．５メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000１メートル')
# (46, '350000', '西部', '350010', '2024-12-06T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風\u3000やや強く', '２．５メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000１メートル')
# (46, '350000', '西部', '350010', '2024-12-07T00:00:00+09:00', '200', 'くもり', '北西の風', '２．５メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000１メートル')
# (46, '350000', '西部', '350010', '2024-12-06T11:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風\u3000やや強く', '２．５メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000１メートル')
# (46, '350000', '西部', '350010', '2024-12-08T00:00:00+09:00', '206', 'くもり\u3000一時\u3000雨か雪', '北西の風', '２．５メートル\u3000ただし\u3000瀬戸内側\u3000では\u3000１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_47
# テーブル weather_forecast_areas_010900_47 のデータ:
# (47, '400000', '福岡地方', '400010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# (47, '400000', '福岡地方', '400010', '2024-12-06T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '２．５メートル')
# (47, '400000', '福岡地方', '400010', '2024-12-07T00:00:00+09:00', '200', 'くもり', '北西の風\u3000後\u3000北の風', '２メートル')
# (47, '400000', '福岡地方', '400010', '2024-12-06T11:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '２．５メートル\u3000後\u3000２メートル')
# (47, '400000', '福岡地方', '400010', '2024-12-08T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '北西の風\u3000後\u3000北の風', '２メートル\u3000後\u3000２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_48
# テーブル weather_forecast_areas_010900_48 のデータ:
# (48, '410000', '南部', '410010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雨', '西の風\u3000後\u3000南西の風', '０．５メートル')
# (48, '410000', '南部', '410010', '2024-12-06T00:00:00+09:00', '200', 'くもり\u3000夜\u3000晴れ\u3000所により\u3000明け方\u3000から\u3000昼過ぎ\u3000雨', '西の風', '０．５メートル')
# (48, '410000', '南部', '410010', '2024-12-07T00:00:00+09:00', '200', 'くもり', '北西の風\u3000後\u3000北の風', '０．５メートル')
# (48, '410000', '南部', '410010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000夕方\u3000まで\u3000雨', '西の風', '０．５メートル')
# (48, '410000', '南部', '410010', '2024-12-08T00:00:00+09:00', '102', '晴れ\u3000一時\u3000雨', '北西の風\u3000後\u3000北の風', '０．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_49
# テーブル weather_forecast_areas_010900_49 のデータ:
# (49, '420000', '南部', '420010', '2024-12-05T17:00:00+09:00', '201', 'くもり\u3000夜のはじめ頃\u3000晴れ\u3000所により\u3000雨', '北西の風\u3000後\u3000西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル')
# (49, '420000', '南部', '420010', '2024-12-06T00:00:00+09:00', '200', 'くもり\u3000所により\u3000雨', '西の風\u3000後\u3000北西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１．５メートル')
# (49, '420000', '南部', '420010', '2024-12-07T00:00:00+09:00', '200', 'くもり', '北の風\u3000後\u3000北西の風', '１．５メートル')
# (49, '420000', '南部', '420010', '2024-12-06T11:00:00+09:00', '200', 'くもり\u3000所により\u3000夕方\u3000まで\u3000雨', '西の風\u3000後\u3000北西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１．５メートル')
# (49, '420000', '南部', '420010', '2024-12-08T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '西の風\u3000後\u3000北の風', '２メートル\u3000後\u3000２．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_50
# テーブル weather_forecast_areas_010900_50 のデータ:
# (50, '430000', '熊本地方', '430010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜\u3000晴れ', '西の風\u3000後\u3000南の風', '０．５メートル')
# (50, '430000', '熊本地方', '430010', '2024-12-06T00:00:00+09:00', '200', 'くもり\u3000夜\u3000晴れ\u3000所により\u3000昼前\u3000から\u3000夜のはじめ頃\u3000雨', '東の風\u3000後\u3000北西の風', '０．５メートル')
# (50, '430000', '熊本地方', '430010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北の風', '０．５メートル')
# (50, '430000', '熊本地方', '430010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ\u3000所により\u3000昼過ぎ\u3000から\u3000雨', '西の風\u3000後\u3000北西の風', '０．５メートル')
# (50, '430000', '熊本地方', '430010', '2024-12-08T00:00:00+09:00', '206', 'くもり\u3000一時\u3000雨か雪', '北の風', '０．５メートル\u3000後\u3000１メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_010900_51
# テーブル weather_forecast_areas_010900_51 のデータ:
# (51, '440000', '中部', '440010', '2024-12-05T17:00:00+09:00', '100', '晴れ', '西の風\u3000後\u3000南の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (51, '440000', '中部', '440010', '2024-12-06T00:00:00+09:00', '110', '晴れ\u3000昼前\u3000から\u3000時々\u3000くもり', '南の風\u3000後\u3000西の風\u3000海上\u3000では\u3000西の風\u3000やや強く', '１メートル')
# (51, '440000', '中部', '440010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '南の風\u3000後\u3000北の風', '１メートル')
# (51, '440000', '中部', '440010', '2024-12-06T11:00:00+09:00', '101', '晴れ\u3000昼過ぎ\u3000から\u3000夕方\u3000くもり', '西の風\u3000海上\u3000では\u3000北西の風\u3000やや強く', '１メートル')
# (51, '440000', '中部', '440010', '2024-12-08T00:00:00+09:00', '211', 'くもり\u3000後\u3000晴れ', '北西の風', '１メートル\u3000後\u3000１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011000_52
# テーブル weather_forecast_areas_011000_52 のデータ:
# (52, '450000', '南部平野部', '450010', '2024-12-05T17:00:00+09:00', '100', '晴れ', '西の風\u3000やや強く', '１メートル')
# (52, '450000', '南部平野部', '450010', '2024-12-06T00:00:00+09:00', '101', '晴れ\u3000昼前\u3000から\u3000夕方\u3000くもり', '西の風', '１メートル')
# (52, '450000', '南部平野部', '450010', '2024-12-07T00:00:00+09:00', '101', '晴れ\u3000時々\u3000くもり', '北西の風', '１メートル')
# (52, '450000', '南部平野部', '450010', '2024-12-06T11:00:00+09:00', '100', '晴れ', '西の風', '１メートル')
# (52, '450000', '南部平野部', '450010', '2024-12-08T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', '１メートル\u3000後\u3000１．５メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011000_54
# テーブル weather_forecast_areas_011000_54 のデータ:
# (54, '460100', '薩摩地方', '460010', '2024-12-05T17:00:00+09:00', '211', 'くもり\u3000夜遅く\u3000晴れ', '北西の風\u3000海上\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', '１．５メートル')
# (54, '460100', '薩摩地方', '460010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000朝晩\u3000晴れ', '北西の風', '１．５メートル')
# (54, '460100', '薩摩地方', '460010', '2024-12-07T00:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', '１メートル\u3000後\u3000１．５メートル')
# (54, '460100', '薩摩地方', '460010', '2024-12-06T11:00:00+09:00', '201', 'くもり\u3000時々\u3000晴れ', '北西の風', '１．５メートル')
# (54, '460100', '薩摩地方', '460010', '2024-12-08T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '北西の風\u3000後\u3000やや強く', '１．５メートル\u3000後\u3000３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011100_55
# テーブル weather_forecast_areas_011100_55 のデータ:
# (55, '471000', '本島中南部', '471010', '2024-12-05T17:00:00+09:00', '200', 'くもり', '北の風\u3000後\u3000北東の風', '１．５メートル')
# (55, '471000', '本島中南部', '471010', '2024-12-06T00:00:00+09:00', '201', 'くもり\u3000昼前\u3000まで\u3000時々\u3000晴れ\u3000所により\u3000夜遅く\u3000雨', '北東の風', '１．５メートル')
# (55, '471000', '本島中南部', '471010', '2024-12-07T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '北東の風\u3000後\u3000やや強く', '１．５メートル\u3000後\u3000２メートル')
# (55, '471000', '本島中南部', '471010', '2024-12-06T11:00:00+09:00', '200', 'くもり\u3000所により\u3000夜遅く\u3000雨', '北東の風', '１．５メートル')
# (55, '471000', '本島中南部', '471010', '2024-12-08T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '北の風\u3000強く\u3000後\u3000やや強く', '３メートル\u3000後\u3000４メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011100_56
# テーブル weather_forecast_areas_011100_56 のデータ:
# (56, '472000', '大東島地方', '472000', '2024-12-05T17:00:00+09:00', '111', '晴れ\u3000夜\u3000くもり', '北の風', '２メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-06T00:00:00+09:00', '210', 'くもり\u3000昼過ぎ\u3000から\u3000時々\u3000晴れ', '北東の風', '１．５メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-07T00:00:00+09:00', '200', 'くもり', '北東の風\u3000後\u3000東の風', '１．５メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-06T11:00:00+09:00', '111', '晴れ\u3000夕方\u3000から\u3000くもり', '北東の風', '１．５メートル')
# (56, '472000', '大東島地方', '472000', '2024-12-08T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '南東の風\u3000後\u3000北の風\u3000強く', '１．５メートル\u3000後\u3000３メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011100_57
# テーブル weather_forecast_areas_011100_57 のデータ:
# (57, '473000', '宮古島地方', '473000', '2024-12-05T17:00:00+09:00', '203', 'くもり\u3000夜のはじめ頃\u3000雨', '北東の風\u3000やや強く', '２メートル')
# (57, '473000', '宮古島地方', '473000', '2024-12-06T00:00:00+09:00', '212', 'くもり\u3000夜\u3000雨', '東の風\u3000やや強く\u3000後\u3000北東の風\u3000やや強く', '２．５メートル')
# (57, '473000', '宮古島地方', '473000', '2024-12-07T00:00:00+09:00', '203', 'くもり\u3000時々\u3000雨', '北東の風\u3000やや強く', '２．５メートル\u3000後\u3000３メートル')
# (57, '473000', '宮古島地方', '473000', '2024-12-06T11:00:00+09:00', '202', 'くもり\u3000昼過ぎ\u3000一時\u3000雨', '東の風\u3000やや強く', '２．５メートル')
# (57, '473000', '宮古島地方', '473000', '2024-12-08T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '北の風\u3000強く\u3000後\u3000やや強く', '４メートル')
# --------------------------------------------------
# テーブル名: weather_forecast_areas_011100_58
# テーブル weather_forecast_areas_011100_58 のデータ:
# (58, '474000', '石垣島地方', '474010', '2024-12-05T17:00:00+09:00', '200', 'くもり\u3000所により\u3000夜\u3000雨', '北東の風\u3000やや強く', '２メートル\u3000後\u3000２．５メートル')
# (58, '474000', '石垣島地方', '474010', '2024-12-06T00:00:00+09:00', '213', 'くもり\u3000昼過ぎ\u3000から\u3000時々\u3000雨', '東の風\u3000やや強く\u3000後\u3000北東の風\u3000やや強く', '２．５メートル')
# (58, '474000', '石垣島地方', '474010', '2024-12-07T00:00:00+09:00', '203', 'くもり\u3000時々\u3000雨', '北東の風\u3000やや強く', '２．５メートル\u3000後\u3000３メートル')
# (58, '474000', '石垣島地方', '474010', '2024-12-06T11:00:00+09:00', '302', '雨\u3000時々\u3000くもり', '北東の風\u3000やや強く', '２メートル')
# (58, '474000', '石垣島地方', '474010', '2024-12-08T00:00:00+09:00', '202', 'くもり\u3000一時\u3000雨', '北の風\u3000強く\u3000後\u3000やや強く', '４メートル')
# --------------------------------------------------
# データベースの作成とデータ挿入が完了しました。
